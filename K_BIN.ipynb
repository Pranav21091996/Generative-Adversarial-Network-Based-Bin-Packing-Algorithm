# %%
import glob
import h5py
import numpy as np
import scipy.misc
import random
import cv2



class Args :
    # dataset size... Use positive number to sample subset of the full dataset.
    dataset_sz = 50000

    # Archive outputs of training here for animating later.
    bin_dir = "bin"

    # images size we will work on. (sz, sz, 3)
    sz = 64
    
    # alpha, used by leaky relu of D and G networks.
    alpha_D = 0.2
    alpha_G = 0.2

    # batch size, during training.
    batch_sz = 64

    # Length of the noise vector to generate the faces from.
    # Latent space z
    noise_shape = (1, 1, 100)

    # GAN training can be ruined any moment if not careful.
    # Archive some snapshots in this directory.
    snapshot_dir = "./snapshots"

    # dropout probability
    dropout = 0.3

    # noisy label magnitude
    label_noise = 0.1

    # history to keep. Slower training but higher quality.
    history_sz = 8

    genw = "gen.hdf5"
    discw = "disc.hdf5"

    # Weight initialization function.
    #kernel_initializer = 'Orthogonal'
    #kernel_initializer = 'RandomNormal'
    # Same as default in Keras, but good for GAN, says
    # https://github.com/gheinrich/DIGITS-GAN/blob/master/examples/weight-init/README.md#experiments-with-lenet-on-mnist
    kernel_initializer = 'glorot_uniform'

    # Since DCGAN paper, everybody uses 0.5 and for me, it works the best too.
    # I tried 0.9, 0.1.
    adam_beta = 0.5

    # BatchNormalization matters too.
    bn_momentum = 0.3

def normalize4gan(im):
    '''
    Convert colorspace and
    cale the input in [-1, 1] range, as described in ganhacks
    '''
    im = im.astype(np.float32)
    im /= 128.0
    im -= 1.0 # now in [-1, 1]
    return im

def denormalize4gan(im):
    '''
    Does opposite of normalize4gan:
    [-1, 1] to [0, 255].
    Warning: input im is modified in-place!
    '''
    im += 1.0 # in [0, 2]
    im *= 127.0 # in [0, 255]
    return im.astype(np.uint8)

def make_hdf5(ofname, wildcard):
    '''
    Preprocess files given by wildcard and save them in hdf5 file, as ofname.
    '''
    pool = list(glob.glob(wildcard))
    if Args.dataset_sz <= 0:
        fnames = pool
    else:
        fnames = []
        for i in range(Args.dataset_sz):
            # possible duplicate but don't care
            fnames.append(random.choice(pool))

    with h5py.File(ofname, "w") as f:
        bins = f.create_dataset("bins", (len(fnames), Args.sz, Args.sz, 3), dtype='f')

        for i, fname in enumerate(fnames):
            print(fname)
            im = scipy.misc.imread(fname, mode='RGB') # some have alpha channel
            im = scipy.misc.imresize(im, (Args.sz, Args.sz))
            bins[i] = normalize4gan(im)



def test(hdff):
    '''
    Reads in hdf file and check if pixels are scaled in [-1, 1] range.
    '''
    with h5py.File(hdff, "r") as f:
        X = f.get("bins")
        print(np.min(X[:,:,:,0]))
        print(np.max(X[:,:,:,0]))
        print(np.min(X[:,:,:,1]))
        print(np.max(X[:,:,:,1]))
        print(np.min(X[:,:,:,2]))
        print(np.max(X[:,:,:,2]))
        print("Dataset size:", len(X))
        assert np.max(X) <= 1.0
        assert np.min(X) >= -1.0



make_hdf5("data.hdf5", "./DataSet1/Bin*.jpg")
# Uncomment and run test, if you want.
test("data.hdf5")
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ./DataSet1/Bin2496.jpg
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:99: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:100: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# ./DataSet1/Bin729.jpg
# ./DataSet1/Bin31484.jpg
# ./DataSet1/Bin6665.jpg
# ./DataSet1/Bin18831.jpg
# ./DataSet1/Bin10091.jpg
# ./DataSet1/Bin35835.jpg
# ./DataSet1/Bin26275.jpg
# ./DataSet1/Bin45512.jpg
# ./DataSet1/Bin34492.jpg
# ./DataSet1/Bin154.jpg
# ./DataSet1/Bin4529.jpg
# ./DataSet1/Bin33736.jpg
# ./DataSet1/Bin10998.jpg
# ./DataSet1/Bin48263.jpg
# ./DataSet1/Bin23747.jpg
# ./DataSet1/Bin2314.jpg
# ./DataSet1/Bin36565.jpg
# ./DataSet1/Bin9610.jpg
# ./DataSet1/Bin48793.jpg
# ./DataSet1/Bin22806.jpg
# ./DataSet1/Bin25776.jpg
# ./DataSet1/Bin24054.jpg
# ./DataSet1/Bin42705.jpg
# ./DataSet1/Bin28953.jpg
# ./DataSet1/Bin18439.jpg
# ./DataSet1/Bin10272.jpg
# ./DataSet1/Bin3333.jpg
# ./DataSet1/Bin19554.jpg
# ./DataSet1/Bin41386.jpg
# ./DataSet1/Bin25886.jpg
# ./DataSet1/Bin32528.jpg
# ./DataSet1/Bin15350.jpg
# ./DataSet1/Bin49245.jpg
# ./DataSet1/Bin5715.jpg
# ./DataSet1/Bin49226.jpg
# ./DataSet1/Bin41464.jpg
# ./DataSet1/Bin2604.jpg
# ./DataSet1/Bin36088.jpg
# ./DataSet1/Bin4987.jpg
# ./DataSet1/Bin14151.jpg
# ./DataSet1/Bin19539.jpg
# ./DataSet1/Bin34707.jpg
# ./DataSet1/Bin39326.jpg
# ./DataSet1/Bin33767.jpg
# ./DataSet1/Bin20023.jpg
# ./DataSet1/Bin30394.jpg
# ./DataSet1/Bin15771.jpg
# ./DataSet1/Bin39682.jpg
# ./DataSet1/Bin8370.jpg
# ./DataSet1/Bin38179.jpg
# ./DataSet1/Bin38919.jpg
# ./DataSet1/Bin19425.jpg
# ./DataSet1/Bin46594.jpg
# ./DataSet1/Bin2524.jpg
# ./DataSet1/Bin42179.jpg
# ./DataSet1/Bin34238.jpg
# ./DataSet1/Bin39909.jpg
# ./DataSet1/Bin24805.jpg
# ./DataSet1/Bin12574.jpg
# ./DataSet1/Bin9541.jpg
# ./DataSet1/Bin9564.jpg
# ./DataSet1/Bin21984.jpg
# ./DataSet1/Bin19463.jpg
# ./DataSet1/Bin41501.jpg
# ./DataSet1/Bin9628.jpg
# ./DataSet1/Bin29123.jpg
# ./DataSet1/Bin49961.jpg
# ./DataSet1/Bin47713.jpg
# ./DataSet1/Bin21722.jpg
# ./DataSet1/Bin36828.jpg
# ./DataSet1/Bin27865.jpg
# ./DataSet1/Bin30128.jpg
# ./DataSet1/Bin41899.jpg
# ./DataSet1/Bin7042.jpg
# ./DataSet1/Bin23808.jpg
# ./DataSet1/Bin12194.jpg
# ./DataSet1/Bin21074.jpg
# ./DataSet1/Bin37072.jpg
# ./DataSet1/Bin18458.jpg
# ./DataSet1/Bin31205.jpg
# ./DataSet1/Bin7034.jpg
# ./DataSet1/Bin40232.jpg
# ./DataSet1/Bin14006.jpg
# ./DataSet1/Bin11561.jpg
# ./DataSet1/Bin32185.jpg
# ./DataSet1/Bin39842.jpg
# ./DataSet1/Bin21597.jpg
# ./DataSet1/Bin7485.jpg
# ./DataSet1/Bin48729.jpg
# ./DataSet1/Bin23796.jpg
# ./DataSet1/Bin47804.jpg
# ./DataSet1/Bin26603.jpg
# ./DataSet1/Bin45350.jpg
# ./DataSet1/Bin10125.jpg
# ./DataSet1/Bin23795.jpg
# ./DataSet1/Bin8241.jpg
# ./DataSet1/Bin43433.jpg
# ./DataSet1/Bin882.jpg
# ./DataSet1/Bin14641.jpg
# ./DataSet1/Bin34109.jpg
# ./DataSet1/Bin40839.jpg
# ./DataSet1/Bin23775.jpg
# ./DataSet1/Bin36534.jpg
# ./DataSet1/Bin41648.jpg
# ./DataSet1/Bin25698.jpg
# ./DataSet1/Bin32887.jpg
# ./DataSet1/Bin49432.jpg
# ./DataSet1/Bin32715.jpg
# ./DataSet1/Bin26816.jpg
# ./DataSet1/Bin26053.jpg
# ./DataSet1/Bin38978.jpg
# ./DataSet1/Bin21900.jpg
# ./DataSet1/Bin15644.jpg
# ./DataSet1/Bin11280.jpg
# ./DataSet1/Bin14069.jpg
# ./DataSet1/Bin39646.jpg
# ./DataSet1/Bin34254.jpg
# ./DataSet1/Bin3577.jpg
# ./DataSet1/Bin9729.jpg
# ./DataSet1/Bin5531.jpg
# ./DataSet1/Bin26642.jpg
# ./DataSet1/Bin34305.jpg
# ./DataSet1/Bin18749.jpg
# ./DataSet1/Bin8493.jpg
# ./DataSet1/Bin39267.jpg
# ./DataSet1/Bin48962.jpg
# ./DataSet1/Bin42257.jpg
# ./DataSet1/Bin41714.jpg
# ./DataSet1/Bin31085.jpg
# ./DataSet1/Bin37262.jpg
# ./DataSet1/Bin49641.jpg
# ./DataSet1/Bin40907.jpg
# ./DataSet1/Bin41041.jpg
# ./DataSet1/Bin10652.jpg
# ./DataSet1/Bin24173.jpg
# ./DataSet1/Bin949.jpg
# ./DataSet1/Bin25632.jpg
# ./DataSet1/Bin8309.jpg
# ./DataSet1/Bin34466.jpg
# ./DataSet1/Bin3811.jpg
# ./DataSet1/Bin40157.jpg
# ./DataSet1/Bin2817.jpg
# ./DataSet1/Bin31951.jpg
# ./DataSet1/Bin5964.jpg
# ./DataSet1/Bin49290.jpg
# ./DataSet1/Bin28806.jpg
# ./DataSet1/Bin6047.jpg
# ./DataSet1/Bin49514.jpg
# ./DataSet1/Bin25680.jpg
# ./DataSet1/Bin12665.jpg
# ./DataSet1/Bin36418.jpg
# ./DataSet1/Bin20691.jpg
# ./DataSet1/Bin20757.jpg
# ./DataSet1/Bin30050.jpg
# ./DataSet1/Bin47462.jpg
# ./DataSet1/Bin35506.jpg
# ./DataSet1/Bin46155.jpg
# ./DataSet1/Bin45613.jpg
# ./DataSet1/Bin37472.jpg
# ./DataSet1/Bin41790.jpg
# ./DataSet1/Bin6215.jpg
# ./DataSet1/Bin20136.jpg
# ./DataSet1/Bin35679.jpg
# ./DataSet1/Bin44697.jpg
# ./DataSet1/Bin30123.jpg
# ./DataSet1/Bin3138.jpg
# ./DataSet1/Bin26185.jpg
# ./DataSet1/Bin3659.jpg
# ./DataSet1/Bin37627.jpg
# ./DataSet1/Bin20024.jpg
# ./DataSet1/Bin13989.jpg
# ./DataSet1/Bin9869.jpg
# ./DataSet1/Bin7812.jpg
# ./DataSet1/Bin47222.jpg
# ./DataSet1/Bin25754.jpg
# ./DataSet1/Bin4701.jpg
# ./DataSet1/Bin1608.jpg
# ./DataSet1/Bin47838.jpg
# ./DataSet1/Bin49727.jpg
# ./DataSet1/Bin6467.jpg
# ./DataSet1/Bin12024.jpg
# ./DataSet1/Bin37708.jpg
# ./DataSet1/Bin3840.jpg
# ./DataSet1/Bin4080.jpg
# ./DataSet1/Bin728.jpg
# ./DataSet1/Bin1314.jpg
# ./DataSet1/Bin33233.jpg
# ./DataSet1/Bin6092.jpg
# ./DataSet1/Bin7212.jpg
# ./DataSet1/Bin8330.jpg
# ./DataSet1/Bin23131.jpg
# ./DataSet1/Bin11009.jpg
# ./DataSet1/Bin6636.jpg
# ./DataSet1/Bin49649.jpg
# ./DataSet1/Bin25128.jpg
# ./DataSet1/Bin373.jpg
# ./DataSet1/Bin43680.jpg
# ./DataSet1/Bin11744.jpg
# ./DataSet1/Bin14067.jpg
# ./DataSet1/Bin47034.jpg
# ./DataSet1/Bin33769.jpg
# ./DataSet1/Bin38275.jpg
# ./DataSet1/Bin11747.jpg
# ./DataSet1/Bin48856.jpg
# ./DataSet1/Bin9506.jpg
# ./DataSet1/Bin20876.jpg
# ./DataSet1/Bin29209.jpg
# ./DataSet1/Bin12072.jpg
# ./DataSet1/Bin9793.jpg
# ./DataSet1/Bin10508.jpg
# ./DataSet1/Bin11138.jpg
# ./DataSet1/Bin7262.jpg
# ./DataSet1/Bin7358.jpg
# ./DataSet1/Bin4994.jpg
# ./DataSet1/Bin2203.jpg
# ./DataSet1/Bin46467.jpg
# ./DataSet1/Bin35315.jpg
# ./DataSet1/Bin30785.jpg
# ./DataSet1/Bin2725.jpg
# ./DataSet1/Bin49450.jpg
# ./DataSet1/Bin39394.jpg
# ./DataSet1/Bin6319.jpg
# ./DataSet1/Bin47900.jpg
# ./DataSet1/Bin49248.jpg
# ./DataSet1/Bin6524.jpg
# ./DataSet1/Bin46072.jpg
# ./DataSet1/Bin41094.jpg
# ./DataSet1/Bin13094.jpg
# ./DataSet1/Bin7416.jpg
# ./DataSet1/Bin38585.jpg
# ./DataSet1/Bin22017.jpg
# ./DataSet1/Bin10014.jpg
# ./DataSet1/Bin25943.jpg
# ./DataSet1/Bin42197.jpg
# ./DataSet1/Bin44199.jpg
# ./DataSet1/Bin48323.jpg
# ./DataSet1/Bin32125.jpg
# ./DataSet1/Bin9563.jpg
# ./DataSet1/Bin19219.jpg
# ./DataSet1/Bin15111.jpg
# ./DataSet1/Bin30123.jpg
# ./DataSet1/Bin16750.jpg
# ./DataSet1/Bin9473.jpg
# ./DataSet1/Bin40854.jpg
# ./DataSet1/Bin5338.jpg
# ./DataSet1/Bin17869.jpg
# ./DataSet1/Bin38291.jpg
# ./DataSet1/Bin20887.jpg
# ./DataSet1/Bin21985.jpg
# ./DataSet1/Bin1877.jpg
# ./DataSet1/Bin20054.jpg
# ./DataSet1/Bin10409.jpg
# ./DataSet1/Bin18906.jpg
# ./DataSet1/Bin29742.jpg
# ./DataSet1/Bin12335.jpg
# ./DataSet1/Bin2731.jpg
# ./DataSet1/Bin6718.jpg
# ./DataSet1/Bin463.jpg
# ./DataSet1/Bin49917.jpg
# ./DataSet1/Bin29293.jpg
# ./DataSet1/Bin12390.jpg
# ./DataSet1/Bin44450.jpg
# ./DataSet1/Bin39140.jpg
# ./DataSet1/Bin17924.jpg
# ./DataSet1/Bin3307.jpg
# ./DataSet1/Bin29893.jpg
# ./DataSet1/Bin14178.jpg
# ./DataSet1/Bin33184.jpg
# ./DataSet1/Bin19498.jpg
# ./DataSet1/Bin18743.jpg
# ./DataSet1/Bin44470.jpg
# ./DataSet1/Bin33097.jpg
# ./DataSet1/Bin43653.jpg
# ./DataSet1/Bin49737.jpg
# ./DataSet1/Bin2619.jpg
# ./DataSet1/Bin22737.jpg
# ./DataSet1/Bin39338.jpg
# ./DataSet1/Bin42968.jpg
# ./DataSet1/Bin37988.jpg
# ./DataSet1/Bin43938.jpg
# ./DataSet1/Bin36358.jpg
# ./DataSet1/Bin17285.jpg
# ./DataSet1/Bin41931.jpg
# ./DataSet1/Bin17572.jpg
# ./DataSet1/Bin24256.jpg
# ./DataSet1/Bin13146.jpg
# ./DataSet1/Bin11978.jpg
# ./DataSet1/Bin41551.jpg
# ./DataSet1/Bin30618.jpg
# ./DataSet1/Bin23930.jpg
# ./DataSet1/Bin20023.jpg
# ./DataSet1/Bin12424.jpg
# ./DataSet1/Bin16860.jpg
# ./DataSet1/Bin32992.jpg
# ./DataSet1/Bin16502.jpg
# ./DataSet1/Bin21767.jpg
# ./DataSet1/Bin23129.jpg
# ./DataSet1/Bin24226.jpg
# ./DataSet1/Bin33022.jpg
# ./DataSet1/Bin24354.jpg
# ./DataSet1/Bin40834.jpg
# ./DataSet1/Bin45823.jpg
# ./DataSet1/Bin30199.jpg
# ./DataSet1/Bin1846.jpg
# ./DataSet1/Bin43563.jpg
# ./DataSet1/Bin11091.jpg
# ./DataSet1/Bin18951.jpg
# ./DataSet1/Bin49000.jpg
# ./DataSet1/Bin38078.jpg
# ./DataSet1/Bin7376.jpg
# ./DataSet1/Bin48658.jpg
# ./DataSet1/Bin44184.jpg
# ./DataSet1/Bin47632.jpg
# ./DataSet1/Bin32614.jpg
# ./DataSet1/Bin304.jpg
# ./DataSet1/Bin39387.jpg
# ./DataSet1/Bin35517.jpg
# ./DataSet1/Bin41760.jpg
# ./DataSet1/Bin25518.jpg
# ./DataSet1/Bin14839.jpg
# ./DataSet1/Bin18138.jpg
# ./DataSet1/Bin19769.jpg
# ./DataSet1/Bin3230.jpg
# ./DataSet1/Bin20176.jpg
# ./DataSet1/Bin29648.jpg
# ./DataSet1/Bin27036.jpg
# ./DataSet1/Bin46674.jpg
# ./DataSet1/Bin13412.jpg
# ./DataSet1/Bin45824.jpg
# ./DataSet1/Bin13795.jpg
# ./DataSet1/Bin36459.jpg
# ./DataSet1/Bin29284.jpg
# ./DataSet1/Bin23738.jpg
# ./DataSet1/Bin8057.jpg
# ./DataSet1/Bin36382.jpg
# ./DataSet1/Bin6334.jpg
# ./DataSet1/Bin41626.jpg
# ./DataSet1/Bin44712.jpg
# ./DataSet1/Bin26875.jpg
# ./DataSet1/Bin30252.jpg
# ./DataSet1/Bin38325.jpg
# ./DataSet1/Bin10906.jpg
# ./DataSet1/Bin24247.jpg
# ./DataSet1/Bin34941.jpg
# ./DataSet1/Bin25493.jpg
# ./DataSet1/Bin49288.jpg
# ./DataSet1/Bin32346.jpg
# ./DataSet1/Bin38480.jpg
# ./DataSet1/Bin26391.jpg
# ./DataSet1/Bin15227.jpg
# ./DataSet1/Bin23939.jpg
# ./DataSet1/Bin15944.jpg
# ./DataSet1/Bin14633.jpg
# ./DataSet1/Bin9169.jpg
# ./DataSet1/Bin25803.jpg
# ./DataSet1/Bin21456.jpg
# ./DataSet1/Bin36799.jpg
# ./DataSet1/Bin34085.jpg
# ./DataSet1/Bin6774.jpg
# ./DataSet1/Bin30541.jpg
# ./DataSet1/Bin39893.jpg
# ./DataSet1/Bin1009.jpg
# ./DataSet1/Bin29260.jpg
# ./DataSet1/Bin46078.jpg
# ./DataSet1/Bin43150.jpg
# ./DataSet1/Bin8728.jpg
# ./DataSet1/Bin31657.jpg
# ./DataSet1/Bin37079.jpg
# ./DataSet1/Bin11064.jpg
# ./DataSet1/Bin14885.jpg
# ./DataSet1/Bin381.jpg
# ./DataSet1/Bin13704.jpg
# ./DataSet1/Bin23407.jpg
# ./DataSet1/Bin5931.jpg
# ./DataSet1/Bin15827.jpg
# ./DataSet1/Bin44669.jpg
# ./DataSet1/Bin37480.jpg
# ./DataSet1/Bin8340.jpg
# ./DataSet1/Bin13732.jpg
# ./DataSet1/Bin15684.jpg
# ./DataSet1/Bin12756.jpg
# ./DataSet1/Bin1474.jpg
# ./DataSet1/Bin45102.jpg
# ./DataSet1/Bin22574.jpg
# ./DataSet1/Bin48385.jpg
# ./DataSet1/Bin30172.jpg
# ./DataSet1/Bin16567.jpg
# ./DataSet1/Bin4270.jpg
# ./DataSet1/Bin15995.jpg
# ./DataSet1/Bin49131.jpg
# ./DataSet1/Bin11800.jpg
# ./DataSet1/Bin35221.jpg
# ./DataSet1/Bin17713.jpg
# ./DataSet1/Bin18541.jpg
# ./DataSet1/Bin32439.jpg
# ./DataSet1/Bin431.jpg
# ./DataSet1/Bin34989.jpg
# ./DataSet1/Bin3702.jpg
# ./DataSet1/Bin38272.jpg
# ./DataSet1/Bin17656.jpg
# ./DataSet1/Bin40894.jpg
# ./DataSet1/Bin37654.jpg
# ./DataSet1/Bin36761.jpg
# ./DataSet1/Bin30753.jpg
# ./DataSet1/Bin39026.jpg
# ./DataSet1/Bin41593.jpg
# ./DataSet1/Bin4539.jpg
# ./DataSet1/Bin3408.jpg
# ./DataSet1/Bin43092.jpg
# ./DataSet1/Bin45162.jpg
# ./DataSet1/Bin47260.jpg
# ./DataSet1/Bin25024.jpg
# ./DataSet1/Bin2344.jpg
# ./DataSet1/Bin30361.jpg
# ./DataSet1/Bin35116.jpg
# ./DataSet1/Bin38015.jpg
# ./DataSet1/Bin42703.jpg
# ./DataSet1/Bin1489.jpg
# ./DataSet1/Bin10896.jpg
# ./DataSet1/Bin2406.jpg
# ./DataSet1/Bin34365.jpg
# ./DataSet1/Bin29486.jpg
# ./DataSet1/Bin33765.jpg
# ./DataSet1/Bin1918.jpg
# ./DataSet1/Bin6187.jpg
# ./DataSet1/Bin25624.jpg
# ./DataSet1/Bin21198.jpg
# ./DataSet1/Bin41774.jpg
# ./DataSet1/Bin36916.jpg
# ./DataSet1/Bin13893.jpg
# ./DataSet1/Bin7721.jpg
# ./DataSet1/Bin6202.jpg
# ./DataSet1/Bin34433.jpg
# ./DataSet1/Bin5751.jpg
# ./DataSet1/Bin6261.jpg
# ./DataSet1/Bin35976.jpg
# ./DataSet1/Bin526.jpg
# ./DataSet1/Bin31315.jpg
# ./DataSet1/Bin8440.jpg
# ./DataSet1/Bin1933.jpg
# ./DataSet1/Bin24715.jpg
# ./DataSet1/Bin36453.jpg
# ./DataSet1/Bin48358.jpg
# ./DataSet1/Bin46616.jpg
# ./DataSet1/Bin36780.jpg
# ./DataSet1/Bin34938.jpg
# ./DataSet1/Bin27671.jpg
# ./DataSet1/Bin45110.jpg
# ./DataSet1/Bin24508.jpg
# ./DataSet1/Bin12052.jpg
# ./DataSet1/Bin35234.jpg
# ./DataSet1/Bin23293.jpg
# ./DataSet1/Bin25015.jpg
# ./DataSet1/Bin13057.jpg
# ./DataSet1/Bin6580.jpg
# ./DataSet1/Bin5789.jpg
# ./DataSet1/Bin38122.jpg
# ./DataSet1/Bin25089.jpg
# ./DataSet1/Bin295.jpg
# ./DataSet1/Bin26002.jpg
# ./DataSet1/Bin24281.jpg
# ./DataSet1/Bin31301.jpg
# ./DataSet1/Bin7551.jpg
# ./DataSet1/Bin49057.jpg
# ./DataSet1/Bin27056.jpg
# ./DataSet1/Bin20035.jpg
# ./DataSet1/Bin13736.jpg
# ./DataSet1/Bin48357.jpg
# ./DataSet1/Bin29321.jpg
# ./DataSet1/Bin17903.jpg
# ./DataSet1/Bin47084.jpg
# ./DataSet1/Bin15914.jpg
# ./DataSet1/Bin32341.jpg
# ./DataSet1/Bin9136.jpg
# ./DataSet1/Bin39373.jpg
# ./DataSet1/Bin15450.jpg
# ./DataSet1/Bin1688.jpg
# ./DataSet1/Bin22568.jpg
# ./DataSet1/Bin28912.jpg
# ./DataSet1/Bin43425.jpg
# ./DataSet1/Bin35056.jpg
# ./DataSet1/Bin47632.jpg
# ./DataSet1/Bin34471.jpg
# ./DataSet1/Bin34146.jpg
# ./DataSet1/Bin49691.jpg
# ./DataSet1/Bin32403.jpg
# ./DataSet1/Bin17698.jpg
# ./DataSet1/Bin26830.jpg
# ./DataSet1/Bin8911.jpg
# ./DataSet1/Bin24189.jpg
# ./DataSet1/Bin4759.jpg
# ./DataSet1/Bin35945.jpg
# ./DataSet1/Bin6046.jpg
# ./DataSet1/Bin3801.jpg
# ./DataSet1/Bin35330.jpg
# ./DataSet1/Bin33329.jpg
# ./DataSet1/Bin43961.jpg
# ./DataSet1/Bin33199.jpg
# ./DataSet1/Bin47209.jpg
# ./DataSet1/Bin14264.jpg
# ./DataSet1/Bin20491.jpg
# ./DataSet1/Bin5484.jpg
# ./DataSet1/Bin37824.jpg
# ./DataSet1/Bin45077.jpg
# ./DataSet1/Bin44181.jpg
# ./DataSet1/Bin4979.jpg
# ./DataSet1/Bin27167.jpg
# ./DataSet1/Bin38388.jpg
# ./DataSet1/Bin49439.jpg
# ./DataSet1/Bin21779.jpg
# ./DataSet1/Bin12518.jpg
# ./DataSet1/Bin102.jpg
# ./DataSet1/Bin35424.jpg
# ./DataSet1/Bin31176.jpg
# ./DataSet1/Bin49188.jpg
# ./DataSet1/Bin992.jpg
# ./DataSet1/Bin16476.jpg
# ./DataSet1/Bin35785.jpg
# ./DataSet1/Bin21929.jpg
# ./DataSet1/Bin13719.jpg
# ./DataSet1/Bin12733.jpg
# ./DataSet1/Bin37525.jpg
# ./DataSet1/Bin18491.jpg
# ./DataSet1/Bin27794.jpg
# ./DataSet1/Bin3389.jpg
# ./DataSet1/Bin26929.jpg
# ./DataSet1/Bin44234.jpg
# ./DataSet1/Bin4418.jpg
# ./DataSet1/Bin7142.jpg
# ./DataSet1/Bin36030.jpg
# ./DataSet1/Bin18490.jpg
# ./DataSet1/Bin40162.jpg
# ./DataSet1/Bin8046.jpg
# ./DataSet1/Bin6902.jpg
# ./DataSet1/Bin47882.jpg
# ./DataSet1/Bin26102.jpg
# ./DataSet1/Bin46688.jpg
# ./DataSet1/Bin12200.jpg
# ./DataSet1/Bin47705.jpg
# ./DataSet1/Bin31195.jpg
# ./DataSet1/Bin16241.jpg
# ./DataSet1/Bin1197.jpg
# ./DataSet1/Bin41421.jpg
# ./DataSet1/Bin819.jpg
# ./DataSet1/Bin34030.jpg
# ./DataSet1/Bin6801.jpg
# ./DataSet1/Bin32874.jpg
# ./DataSet1/Bin14689.jpg
# ./DataSet1/Bin16153.jpg
# ./DataSet1/Bin16855.jpg
# ./DataSet1/Bin15486.jpg
# ./DataSet1/Bin2958.jpg
# ./DataSet1/Bin14527.jpg
# ./DataSet1/Bin23892.jpg
# ./DataSet1/Bin36266.jpg
# ./DataSet1/Bin24831.jpg
# ./DataSet1/Bin14625.jpg
# ./DataSet1/Bin47297.jpg
# ./DataSet1/Bin20522.jpg
# ./DataSet1/Bin15440.jpg
# ./DataSet1/Bin41379.jpg
# ./DataSet1/Bin35884.jpg
# ./DataSet1/Bin37047.jpg
# ./DataSet1/Bin22616.jpg
# ./DataSet1/Bin41832.jpg
# ./DataSet1/Bin7335.jpg
# ./DataSet1/Bin30680.jpg
# ./DataSet1/Bin23916.jpg
# ./DataSet1/Bin26011.jpg
# ./DataSet1/Bin13875.jpg
# ./DataSet1/Bin27717.jpg
# ./DataSet1/Bin31114.jpg
# ./DataSet1/Bin31122.jpg
# ./DataSet1/Bin6402.jpg
# ./DataSet1/Bin41246.jpg
# ./DataSet1/Bin240.jpg
# ./DataSet1/Bin49901.jpg
# ./DataSet1/Bin28081.jpg
# ./DataSet1/Bin15430.jpg
# ./DataSet1/Bin16759.jpg
# ./DataSet1/Bin20773.jpg
# ./DataSet1/Bin48194.jpg
# ./DataSet1/Bin4521.jpg
# ./DataSet1/Bin47375.jpg
# ./DataSet1/Bin43289.jpg
# ./DataSet1/Bin35410.jpg
# ./DataSet1/Bin20383.jpg
# ./DataSet1/Bin885.jpg
# ./DataSet1/Bin12790.jpg
# ./DataSet1/Bin9710.jpg
# ./DataSet1/Bin41977.jpg
# ./DataSet1/Bin2469.jpg
# ./DataSet1/Bin12366.jpg
# ./DataSet1/Bin43422.jpg
# ./DataSet1/Bin10175.jpg
# ./DataSet1/Bin4612.jpg
# ./DataSet1/Bin16835.jpg
# ./DataSet1/Bin48436.jpg
# ./DataSet1/Bin45091.jpg
# ./DataSet1/Bin37038.jpg
# ./DataSet1/Bin36122.jpg
# ./DataSet1/Bin43929.jpg
# ./DataSet1/Bin20978.jpg
# ./DataSet1/Bin1624.jpg
# ./DataSet1/Bin16743.jpg
# ./DataSet1/Bin39194.jpg
# ./DataSet1/Bin10842.jpg
# ./DataSet1/Bin13620.jpg
# ./DataSet1/Bin3133.jpg
# ./DataSet1/Bin39101.jpg
# ./DataSet1/Bin32205.jpg
# ./DataSet1/Bin28532.jpg
# ./DataSet1/Bin8189.jpg
# ./DataSet1/Bin16522.jpg
# ./DataSet1/Bin23743.jpg
# ./DataSet1/Bin10692.jpg
# ./DataSet1/Bin11227.jpg
# ./DataSet1/Bin6271.jpg
# ./DataSet1/Bin19699.jpg
# ./DataSet1/Bin9772.jpg
# ./DataSet1/Bin41039.jpg
# ./DataSet1/Bin12700.jpg
# ./DataSet1/Bin16659.jpg
# ./DataSet1/Bin14232.jpg
# ./DataSet1/Bin5474.jpg
# ./DataSet1/Bin43834.jpg
# ./DataSet1/Bin26041.jpg
# ./DataSet1/Bin15601.jpg
# ./DataSet1/Bin19265.jpg
# ./DataSet1/Bin46479.jpg
# ./DataSet1/Bin24971.jpg
# ./DataSet1/Bin11815.jpg
# ./DataSet1/Bin41714.jpg
# ./DataSet1/Bin47200.jpg
# ./DataSet1/Bin25522.jpg
# ./DataSet1/Bin7789.jpg
# ./DataSet1/Bin29026.jpg
# ./DataSet1/Bin21607.jpg
# ./DataSet1/Bin39174.jpg
# ./DataSet1/Bin1677.jpg
# ./DataSet1/Bin48227.jpg
# ./DataSet1/Bin19785.jpg
# ./DataSet1/Bin34284.jpg
# ./DataSet1/Bin42710.jpg
# ./DataSet1/Bin32364.jpg
# ./DataSet1/Bin14139.jpg
# ./DataSet1/Bin11866.jpg
# ./DataSet1/Bin24903.jpg
# ./DataSet1/Bin21587.jpg
# ./DataSet1/Bin10001.jpg
# ./DataSet1/Bin38459.jpg
# ./DataSet1/Bin43530.jpg
# ./DataSet1/Bin28818.jpg
# ./DataSet1/Bin34576.jpg
# ./DataSet1/Bin5741.jpg
# ./DataSet1/Bin34671.jpg
# ./DataSet1/Bin12298.jpg
# ./DataSet1/Bin5725.jpg
# ./DataSet1/Bin3340.jpg
# ./DataSet1/Bin18945.jpg
# ./DataSet1/Bin12892.jpg
# ./DataSet1/Bin41457.jpg
# ./DataSet1/Bin22977.jpg
# ./DataSet1/Bin21215.jpg
# ./DataSet1/Bin15232.jpg
# ./DataSet1/Bin31461.jpg
# ./DataSet1/Bin14740.jpg
# ./DataSet1/Bin38799.jpg
# ./DataSet1/Bin23073.jpg
# ./DataSet1/Bin8523.jpg
# ./DataSet1/Bin43490.jpg
# ./DataSet1/Bin25599.jpg
# ./DataSet1/Bin13623.jpg
# ./DataSet1/Bin4013.jpg
# ./DataSet1/Bin38993.jpg
# ./DataSet1/Bin13879.jpg
# ./DataSet1/Bin1629.jpg
# ./DataSet1/Bin20095.jpg
# ./DataSet1/Bin3978.jpg
# ./DataSet1/Bin16802.jpg
# ./DataSet1/Bin1188.jpg
# ./DataSet1/Bin34139.jpg
# ./DataSet1/Bin23278.jpg
# ./DataSet1/Bin35021.jpg
# ./DataSet1/Bin36215.jpg
# ./DataSet1/Bin40618.jpg
# ./DataSet1/Bin20552.jpg
# ./DataSet1/Bin36131.jpg
# ./DataSet1/Bin10610.jpg
# ./DataSet1/Bin30140.jpg
# ./DataSet1/Bin29556.jpg
# ./DataSet1/Bin39806.jpg
# ./DataSet1/Bin9603.jpg
# ./DataSet1/Bin16803.jpg
# ./DataSet1/Bin5160.jpg
# ./DataSet1/Bin2717.jpg
# ./DataSet1/Bin32194.jpg
# ./DataSet1/Bin36113.jpg
# ./DataSet1/Bin26398.jpg
# ./DataSet1/Bin23062.jpg
# ./DataSet1/Bin29567.jpg
# ./DataSet1/Bin8071.jpg
# ./DataSet1/Bin38339.jpg
# ./DataSet1/Bin42008.jpg
# ./DataSet1/Bin42385.jpg
# ./DataSet1/Bin5001.jpg
# ./DataSet1/Bin44031.jpg
# ./DataSet1/Bin36856.jpg
# ./DataSet1/Bin12030.jpg
# ./DataSet1/Bin45691.jpg
# ./DataSet1/Bin19274.jpg
# ./DataSet1/Bin8750.jpg
# ./DataSet1/Bin20669.jpg
# ./DataSet1/Bin15530.jpg
# ./DataSet1/Bin25960.jpg
# ./DataSet1/Bin32212.jpg
# ./DataSet1/Bin186.jpg
# ./DataSet1/Bin42830.jpg
# ./DataSet1/Bin34751.jpg
# ./DataSet1/Bin2022.jpg
# ./DataSet1/Bin39702.jpg
# ./DataSet1/Bin8007.jpg
# ./DataSet1/Bin23956.jpg
# ./DataSet1/Bin29889.jpg
# ./DataSet1/Bin13439.jpg
# ./DataSet1/Bin48465.jpg
# ./DataSet1/Bin129.jpg
# ./DataSet1/Bin33681.jpg
# ./DataSet1/Bin11161.jpg
# ./DataSet1/Bin39858.jpg
# ./DataSet1/Bin42925.jpg
# ./DataSet1/Bin19479.jpg
# ./DataSet1/Bin36524.jpg
# ./DataSet1/Bin37687.jpg
# ./DataSet1/Bin36297.jpg
# ./DataSet1/Bin31678.jpg
# ./DataSet1/Bin7018.jpg
# ./DataSet1/Bin48275.jpg
# ./DataSet1/Bin15734.jpg
# ./DataSet1/Bin11060.jpg
# ./DataSet1/Bin21526.jpg
# ./DataSet1/Bin30285.jpg
# ./DataSet1/Bin5658.jpg
# ./DataSet1/Bin14463.jpg
# ./DataSet1/Bin49777.jpg
# ./DataSet1/Bin1476.jpg
# ./DataSet1/Bin403.jpg
# ./DataSet1/Bin36559.jpg
# ./DataSet1/Bin47163.jpg
# ./DataSet1/Bin2186.jpg
# ./DataSet1/Bin31931.jpg
# ./DataSet1/Bin13014.jpg
# ./DataSet1/Bin1536.jpg
# ./DataSet1/Bin5819.jpg
# ./DataSet1/Bin4379.jpg
# ./DataSet1/Bin27705.jpg
# ./DataSet1/Bin29976.jpg
# ./DataSet1/Bin34184.jpg
# ./DataSet1/Bin36528.jpg
# ./DataSet1/Bin33009.jpg
# ./DataSet1/Bin46612.jpg
# ./DataSet1/Bin13035.jpg
# ./DataSet1/Bin39388.jpg
# ./DataSet1/Bin29380.jpg
# ./DataSet1/Bin19333.jpg
# ./DataSet1/Bin47679.jpg
# ./DataSet1/Bin39610.jpg
# ./DataSet1/Bin15556.jpg
# ./DataSet1/Bin5176.jpg
# ./DataSet1/Bin3009.jpg
# ./DataSet1/Bin8152.jpg
# ./DataSet1/Bin5488.jpg
# ./DataSet1/Bin36622.jpg
# ./DataSet1/Bin7321.jpg
# ./DataSet1/Bin46806.jpg
# ./DataSet1/Bin6312.jpg
# ./DataSet1/Bin38079.jpg
# ./DataSet1/Bin36916.jpg
# ./DataSet1/Bin1355.jpg
# ./DataSet1/Bin42330.jpg
# ./DataSet1/Bin35984.jpg
# ./DataSet1/Bin25947.jpg
# ./DataSet1/Bin958.jpg
# ./DataSet1/Bin29488.jpg
# ./DataSet1/Bin26976.jpg
# ./DataSet1/Bin31796.jpg
# ./DataSet1/Bin49088.jpg
# ./DataSet1/Bin43304.jpg
# ./DataSet1/Bin26720.jpg
# ./DataSet1/Bin18909.jpg
# ./DataSet1/Bin41939.jpg
# ./DataSet1/Bin32946.jpg
# ./DataSet1/Bin38158.jpg
# ./DataSet1/Bin40517.jpg
# ./DataSet1/Bin30682.jpg
# ./DataSet1/Bin29332.jpg
# ./DataSet1/Bin1210.jpg
# ./DataSet1/Bin10146.jpg
# ./DataSet1/Bin24104.jpg
# ./DataSet1/Bin39783.jpg
# ./DataSet1/Bin44191.jpg
# ./DataSet1/Bin11298.jpg
# ./DataSet1/Bin44377.jpg
# ./DataSet1/Bin9296.jpg
# ./DataSet1/Bin16517.jpg
# ./DataSet1/Bin15303.jpg
# ./DataSet1/Bin11519.jpg
# ./DataSet1/Bin40341.jpg
# ./DataSet1/Bin20197.jpg
# ./DataSet1/Bin29455.jpg
# ./DataSet1/Bin36851.jpg
# ./DataSet1/Bin24392.jpg
# ./DataSet1/Bin18402.jpg
# ./DataSet1/Bin25782.jpg
# ./DataSet1/Bin733.jpg
# ./DataSet1/Bin8315.jpg
# ./DataSet1/Bin4940.jpg
# ./DataSet1/Bin7205.jpg
# ./DataSet1/Bin34818.jpg
# ./DataSet1/Bin39765.jpg
# ./DataSet1/Bin30117.jpg
# ./DataSet1/Bin21839.jpg
# ./DataSet1/Bin14106.jpg
# ./DataSet1/Bin38752.jpg
# ./DataSet1/Bin20264.jpg
# ./DataSet1/Bin1455.jpg
# ./DataSet1/Bin9002.jpg
# ./DataSet1/Bin21230.jpg
# ./DataSet1/Bin23038.jpg
# ./DataSet1/Bin20544.jpg
# ./DataSet1/Bin35786.jpg
# ./DataSet1/Bin21964.jpg
# ./DataSet1/Bin23527.jpg
# ./DataSet1/Bin5142.jpg
# ./DataSet1/Bin25636.jpg
# ./DataSet1/Bin39957.jpg
# ./DataSet1/Bin3945.jpg
# ./DataSet1/Bin9926.jpg
# ./DataSet1/Bin32188.jpg
# ./DataSet1/Bin3991.jpg
# ./DataSet1/Bin7254.jpg
# ./DataSet1/Bin7308.jpg
# ./DataSet1/Bin6878.jpg
# ./DataSet1/Bin42703.jpg
# ./DataSet1/Bin31970.jpg
# ./DataSet1/Bin17822.jpg
# ./DataSet1/Bin19637.jpg
# ./DataSet1/Bin35570.jpg
# ./DataSet1/Bin24964.jpg
# ./DataSet1/Bin30491.jpg
# ./DataSet1/Bin13906.jpg
# ./DataSet1/Bin40007.jpg
# ./DataSet1/Bin43032.jpg
# ./DataSet1/Bin23458.jpg
# ./DataSet1/Bin47815.jpg
# ./DataSet1/Bin9102.jpg
# ./DataSet1/Bin2757.jpg
# ./DataSet1/Bin1656.jpg
# ./DataSet1/Bin31412.jpg
# ./DataSet1/Bin26617.jpg
# ./DataSet1/Bin22552.jpg
# ./DataSet1/Bin34857.jpg
# ./DataSet1/Bin34779.jpg
# ./DataSet1/Bin49109.jpg
# ./DataSet1/Bin11780.jpg
# ./DataSet1/Bin23719.jpg
# ./DataSet1/Bin20922.jpg
# ./DataSet1/Bin41585.jpg
# ./DataSet1/Bin8784.jpg
# ./DataSet1/Bin17050.jpg
# ./DataSet1/Bin17695.jpg
# ./DataSet1/Bin13026.jpg
# ./DataSet1/Bin10782.jpg
# ./DataSet1/Bin33890.jpg
# ./DataSet1/Bin7982.jpg
# ./DataSet1/Bin30967.jpg
# ./DataSet1/Bin36425.jpg
# ./DataSet1/Bin36526.jpg
# ./DataSet1/Bin7030.jpg
# ./DataSet1/Bin49851.jpg
# ./DataSet1/Bin247.jpg
# ./DataSet1/Bin17807.jpg
# ./DataSet1/Bin9808.jpg
# ./DataSet1/Bin31321.jpg
# ./DataSet1/Bin13078.jpg
# ./DataSet1/Bin23933.jpg
# ./DataSet1/Bin45694.jpg
# ./DataSet1/Bin43973.jpg
# ./DataSet1/Bin26643.jpg
# ./DataSet1/Bin9098.jpg
# ./DataSet1/Bin8498.jpg
# ./DataSet1/Bin7789.jpg
# ./DataSet1/Bin21650.jpg
# ./DataSet1/Bin24955.jpg
# ./DataSet1/Bin9785.jpg
# ./DataSet1/Bin16674.jpg
# ./DataSet1/Bin45339.jpg
# ./DataSet1/Bin4256.jpg
# ./DataSet1/Bin3674.jpg
# ./DataSet1/Bin9984.jpg
# ./DataSet1/Bin44705.jpg
# ./DataSet1/Bin35167.jpg
# ./DataSet1/Bin4025.jpg
# ./DataSet1/Bin48099.jpg
# ./DataSet1/Bin4017.jpg
# ./DataSet1/Bin25563.jpg
# ./DataSet1/Bin105.jpg
# ./DataSet1/Bin1196.jpg
# ./DataSet1/Bin23922.jpg
# ./DataSet1/Bin14303.jpg
# ./DataSet1/Bin8023.jpg
# ./DataSet1/Bin22358.jpg
# ./DataSet1/Bin20668.jpg
# ./DataSet1/Bin45409.jpg
# ./DataSet1/Bin10826.jpg
# ./DataSet1/Bin22046.jpg
# ./DataSet1/Bin23726.jpg
# ./DataSet1/Bin32568.jpg
# ./DataSet1/Bin42621.jpg
# ./DataSet1/Bin19239.jpg
# ./DataSet1/Bin45437.jpg
# ./DataSet1/Bin18672.jpg
# ./DataSet1/Bin40577.jpg
# ./DataSet1/Bin2055.jpg
# ./DataSet1/Bin2775.jpg
# ./DataSet1/Bin11008.jpg
# ./DataSet1/Bin42984.jpg
# ./DataSet1/Bin39823.jpg
# ./DataSet1/Bin28277.jpg
# ./DataSet1/Bin5248.jpg
# ./DataSet1/Bin45883.jpg
# ./DataSet1/Bin36639.jpg
# ./DataSet1/Bin42643.jpg
# ./DataSet1/Bin18402.jpg
# ./DataSet1/Bin31894.jpg
# ./DataSet1/Bin6976.jpg
# ./DataSet1/Bin34375.jpg
# ./DataSet1/Bin20550.jpg
# ./DataSet1/Bin18516.jpg
# ./DataSet1/Bin13045.jpg
# ./DataSet1/Bin12367.jpg
# ./DataSet1/Bin23849.jpg
# ./DataSet1/Bin14224.jpg
# ./DataSet1/Bin13267.jpg
# ./DataSet1/Bin9038.jpg
# ./DataSet1/Bin46483.jpg
# ./DataSet1/Bin27328.jpg
# ./DataSet1/Bin3496.jpg
# ./DataSet1/Bin2801.jpg
# ./DataSet1/Bin40511.jpg
# ./DataSet1/Bin38138.jpg
# ./DataSet1/Bin37240.jpg
# ./DataSet1/Bin32951.jpg
# ./DataSet1/Bin43460.jpg
# ./DataSet1/Bin20297.jpg
# ./DataSet1/Bin20249.jpg
# ./DataSet1/Bin10145.jpg
# ./DataSet1/Bin33979.jpg
# ./DataSet1/Bin38732.jpg
# ./DataSet1/Bin43133.jpg
# ./DataSet1/Bin37326.jpg
# ./DataSet1/Bin4686.jpg
# ./DataSet1/Bin16862.jpg
# ./DataSet1/Bin47524.jpg
# ./DataSet1/Bin48908.jpg
# ./DataSet1/Bin44291.jpg
# ./DataSet1/Bin18558.jpg
# ./DataSet1/Bin46936.jpg
# ./DataSet1/Bin8857.jpg
# ./DataSet1/Bin8649.jpg
# ./DataSet1/Bin41816.jpg
# ./DataSet1/Bin23537.jpg
# ./DataSet1/Bin24432.jpg
# ./DataSet1/Bin14724.jpg
# ./DataSet1/Bin42448.jpg
# ./DataSet1/Bin35746.jpg
# ./DataSet1/Bin3009.jpg
# ./DataSet1/Bin29830.jpg
# ./DataSet1/Bin41855.jpg
# ./DataSet1/Bin44485.jpg
# ./DataSet1/Bin9928.jpg
# ./DataSet1/Bin17273.jpg
# ./DataSet1/Bin17737.jpg
# ./DataSet1/Bin46601.jpg
# ./DataSet1/Bin10658.jpg
# ./DataSet1/Bin28568.jpg
# ./DataSet1/Bin40990.jpg
# ./DataSet1/Bin6275.jpg
# ./DataSet1/Bin35721.jpg
# ./DataSet1/Bin33198.jpg
# ./DataSet1/Bin46243.jpg
# ./DataSet1/Bin25545.jpg
# ./DataSet1/Bin28957.jpg
# ./DataSet1/Bin663.jpg
# ./DataSet1/Bin10704.jpg
# ./DataSet1/Bin45884.jpg
# ./DataSet1/Bin19107.jpg
# ./DataSet1/Bin43348.jpg
# ./DataSet1/Bin47806.jpg
# ./DataSet1/Bin32064.jpg
# ./DataSet1/Bin21764.jpg
# ./DataSet1/Bin37653.jpg
# ./DataSet1/Bin33136.jpg
# ./DataSet1/Bin11395.jpg
# ./DataSet1/Bin17868.jpg
# ./DataSet1/Bin844.jpg
# ./DataSet1/Bin11144.jpg
# ./DataSet1/Bin5197.jpg
# ./DataSet1/Bin22962.jpg
# ./DataSet1/Bin17049.jpg
# ./DataSet1/Bin47808.jpg
# ./DataSet1/Bin27869.jpg
# ./DataSet1/Bin42744.jpg
# ./DataSet1/Bin29518.jpg
# ./DataSet1/Bin38703.jpg
# ./DataSet1/Bin22607.jpg
# ./DataSet1/Bin47435.jpg
# ./DataSet1/Bin31648.jpg
# ./DataSet1/Bin47590.jpg
# ./DataSet1/Bin5860.jpg
# ./DataSet1/Bin42810.jpg
# ./DataSet1/Bin6224.jpg
# ./DataSet1/Bin17250.jpg
# ./DataSet1/Bin39873.jpg
# ./DataSet1/Bin3570.jpg
# ./DataSet1/Bin43804.jpg
# ./DataSet1/Bin16991.jpg
# ./DataSet1/Bin42854.jpg
# ./DataSet1/Bin41305.jpg
# ./DataSet1/Bin16111.jpg
# ./DataSet1/Bin28989.jpg
# ./DataSet1/Bin23199.jpg
# ./DataSet1/Bin6511.jpg
# ./DataSet1/Bin29718.jpg
# ./DataSet1/Bin47907.jpg
# ./DataSet1/Bin2612.jpg
# ./DataSet1/Bin14107.jpg
# ./DataSet1/Bin1812.jpg
# ./DataSet1/Bin2908.jpg
# ./DataSet1/Bin36180.jpg
# ./DataSet1/Bin29401.jpg
# ./DataSet1/Bin43475.jpg
# ./DataSet1/Bin48060.jpg
# ./DataSet1/Bin4772.jpg
# ./DataSet1/Bin36680.jpg
# ./DataSet1/Bin19940.jpg
# ./DataSet1/Bin25497.jpg
# ./DataSet1/Bin22882.jpg
# ./DataSet1/Bin42363.jpg
# ./DataSet1/Bin17974.jpg
# ./DataSet1/Bin10598.jpg
# ./DataSet1/Bin18305.jpg
# ./DataSet1/Bin9413.jpg
# ./DataSet1/Bin23957.jpg
# ./DataSet1/Bin7029.jpg
# ./DataSet1/Bin33013.jpg
# ./DataSet1/Bin3693.jpg
# ./DataSet1/Bin43017.jpg
# ./DataSet1/Bin16190.jpg
# ./DataSet1/Bin47898.jpg
# ./DataSet1/Bin32796.jpg
# ./DataSet1/Bin4795.jpg
# ./DataSet1/Bin509.jpg
# ./DataSet1/Bin28732.jpg
# ./DataSet1/Bin16021.jpg
# ./DataSet1/Bin36375.jpg
# ./DataSet1/Bin23270.jpg
# ./DataSet1/Bin226.jpg
# ./DataSet1/Bin44751.jpg
# ./DataSet1/Bin19108.jpg
# ./DataSet1/Bin32152.jpg
# ./DataSet1/Bin47188.jpg
# ./DataSet1/Bin25837.jpg
# ./DataSet1/Bin5614.jpg
# ./DataSet1/Bin41926.jpg
# ./DataSet1/Bin40152.jpg
# ./DataSet1/Bin20325.jpg
# ./DataSet1/Bin27564.jpg
# ./DataSet1/Bin21604.jpg
# ./DataSet1/Bin10160.jpg
# ./DataSet1/Bin29949.jpg
# ./DataSet1/Bin45686.jpg
# ./DataSet1/Bin23125.jpg
# ./DataSet1/Bin17878.jpg
# ./DataSet1/Bin37929.jpg
# ./DataSet1/Bin19955.jpg
# ./DataSet1/Bin18362.jpg
# ./DataSet1/Bin47589.jpg
# ./DataSet1/Bin29763.jpg
# ./DataSet1/Bin4204.jpg
# ./DataSet1/Bin11088.jpg
# ./DataSet1/Bin10018.jpg
# ./DataSet1/Bin45066.jpg
# ./DataSet1/Bin42715.jpg
# ./DataSet1/Bin44170.jpg
# ./DataSet1/Bin11760.jpg
# ./DataSet1/Bin11729.jpg
# ./DataSet1/Bin30408.jpg
# ./DataSet1/Bin10434.jpg
# ./DataSet1/Bin42751.jpg
# ./DataSet1/Bin12301.jpg
# ./DataSet1/Bin30474.jpg
# ./DataSet1/Bin18191.jpg
# ./DataSet1/Bin13974.jpg
# ./DataSet1/Bin14308.jpg
# ./DataSet1/Bin38915.jpg
# ./DataSet1/Bin5244.jpg
# ./DataSet1/Bin25677.jpg
# ./DataSet1/Bin39595.jpg
# ./DataSet1/Bin22244.jpg
# ./DataSet1/Bin24110.jpg
# ./DataSet1/Bin22461.jpg
# ./DataSet1/Bin43122.jpg
# ./DataSet1/Bin30226.jpg
# ./DataSet1/Bin28534.jpg
# ./DataSet1/Bin3970.jpg
# ./DataSet1/Bin40070.jpg
# ./DataSet1/Bin36077.jpg
# ./DataSet1/Bin15557.jpg
# ./DataSet1/Bin46490.jpg
# ./DataSet1/Bin7966.jpg
# ./DataSet1/Bin20211.jpg
# ./DataSet1/Bin1964.jpg
# ./DataSet1/Bin41147.jpg
# ./DataSet1/Bin8966.jpg
# ./DataSet1/Bin14580.jpg
# ./DataSet1/Bin35356.jpg
# ./DataSet1/Bin12252.jpg
# ./DataSet1/Bin40291.jpg
# ./DataSet1/Bin40971.jpg
# ./DataSet1/Bin43691.jpg
# ./DataSet1/Bin42336.jpg
# ./DataSet1/Bin5414.jpg
# ./DataSet1/Bin14351.jpg
# ./DataSet1/Bin1923.jpg
# ./DataSet1/Bin28695.jpg
# ./DataSet1/Bin16092.jpg
# ./DataSet1/Bin12894.jpg
# ./DataSet1/Bin27638.jpg
# ./DataSet1/Bin25724.jpg
# ./DataSet1/Bin12437.jpg
# ./DataSet1/Bin47610.jpg
# ./DataSet1/Bin8708.jpg
# ./DataSet1/Bin10705.jpg
# ./DataSet1/Bin26968.jpg
# ./DataSet1/Bin19600.jpg
# ./DataSet1/Bin37296.jpg
# ./DataSet1/Bin28409.jpg
# ./DataSet1/Bin15517.jpg
# ./DataSet1/Bin23340.jpg
# ./DataSet1/Bin28642.jpg
# ./DataSet1/Bin47678.jpg
# ./DataSet1/Bin12915.jpg
# ./DataSet1/Bin44341.jpg
# ./DataSet1/Bin672.jpg
# ./DataSet1/Bin31583.jpg
# ./DataSet1/Bin45417.jpg
# ./DataSet1/Bin17380.jpg
# ./DataSet1/Bin31344.jpg
# ./DataSet1/Bin21157.jpg
# ./DataSet1/Bin3939.jpg
# ./DataSet1/Bin38546.jpg
# ./DataSet1/Bin3513.jpg
# ./DataSet1/Bin31455.jpg
# ./DataSet1/Bin19133.jpg
# ./DataSet1/Bin26406.jpg
# ./DataSet1/Bin42911.jpg
# ./DataSet1/Bin33787.jpg
# ./DataSet1/Bin34712.jpg
# ./DataSet1/Bin48765.jpg
# ./DataSet1/Bin35016.jpg
# ./DataSet1/Bin30157.jpg
# ./DataSet1/Bin41907.jpg
# ./DataSet1/Bin6296.jpg
# ./DataSet1/Bin37545.jpg
# ./DataSet1/Bin1032.jpg
# ./DataSet1/Bin4756.jpg
# ./DataSet1/Bin4858.jpg
# ./DataSet1/Bin42804.jpg
# ./DataSet1/Bin1357.jpg
# ./DataSet1/Bin6200.jpg
# ./DataSet1/Bin13706.jpg
# ./DataSet1/Bin4488.jpg
# ./DataSet1/Bin29878.jpg
# ./DataSet1/Bin20616.jpg
# ./DataSet1/Bin4191.jpg
# ./DataSet1/Bin1734.jpg
# ./DataSet1/Bin2454.jpg
# ./DataSet1/Bin46137.jpg
# ./DataSet1/Bin8655.jpg
# ./DataSet1/Bin2122.jpg
# ./DataSet1/Bin37961.jpg
# ./DataSet1/Bin28282.jpg
# ./DataSet1/Bin23719.jpg
# ./DataSet1/Bin141.jpg
# ./DataSet1/Bin8559.jpg
# ./DataSet1/Bin46600.jpg
# ./DataSet1/Bin28640.jpg
# ./DataSet1/Bin7636.jpg
# ./DataSet1/Bin16466.jpg
# ./DataSet1/Bin38440.jpg
# ./DataSet1/Bin23631.jpg
# ./DataSet1/Bin18975.jpg
# ./DataSet1/Bin11549.jpg
# ./DataSet1/Bin40464.jpg
# ./DataSet1/Bin25950.jpg
# ./DataSet1/Bin21227.jpg
# ./DataSet1/Bin35136.jpg
# ./DataSet1/Bin4494.jpg
# ./DataSet1/Bin14875.jpg
# ./DataSet1/Bin9456.jpg
# ./DataSet1/Bin29583.jpg
# ./DataSet1/Bin35140.jpg
# ./DataSet1/Bin24497.jpg
# ./DataSet1/Bin9560.jpg
# ./DataSet1/Bin218.jpg
# ./DataSet1/Bin42386.jpg
# ./DataSet1/Bin49520.jpg
# ./DataSet1/Bin45505.jpg
# ./DataSet1/Bin14734.jpg
# ./DataSet1/Bin26317.jpg
# ./DataSet1/Bin15685.jpg
# ./DataSet1/Bin6880.jpg
# ./DataSet1/Bin15136.jpg
# ./DataSet1/Bin2547.jpg
# ./DataSet1/Bin14096.jpg
# ./DataSet1/Bin41178.jpg
# ./DataSet1/Bin11223.jpg
# ./DataSet1/Bin41017.jpg
# ./DataSet1/Bin40383.jpg
# ./DataSet1/Bin5710.jpg
# ./DataSet1/Bin37043.jpg
# ./DataSet1/Bin45080.jpg
# ./DataSet1/Bin35159.jpg
# ./DataSet1/Bin1170.jpg
# ./DataSet1/Bin16859.jpg
# ./DataSet1/Bin32015.jpg
# ./DataSet1/Bin36977.jpg
# ./DataSet1/Bin7368.jpg
# ./DataSet1/Bin1406.jpg
# ./DataSet1/Bin25773.jpg
# ./DataSet1/Bin3478.jpg
# ./DataSet1/Bin40559.jpg
# ./DataSet1/Bin4412.jpg
# ./DataSet1/Bin20351.jpg
# ./DataSet1/Bin22609.jpg
# ./DataSet1/Bin32363.jpg
# ./DataSet1/Bin44430.jpg
# ./DataSet1/Bin19314.jpg
# ./DataSet1/Bin14790.jpg
# ./DataSet1/Bin18216.jpg
# ./DataSet1/Bin37310.jpg
# ./DataSet1/Bin28104.jpg
# ./DataSet1/Bin24012.jpg
# ./DataSet1/Bin20384.jpg
# ./DataSet1/Bin48231.jpg
# ./DataSet1/Bin11041.jpg
# ./DataSet1/Bin9638.jpg
# ./DataSet1/Bin19898.jpg
# ./DataSet1/Bin8066.jpg
# ./DataSet1/Bin49093.jpg
# ./DataSet1/Bin27273.jpg
# ./DataSet1/Bin21003.jpg
# ./DataSet1/Bin49202.jpg
# ./DataSet1/Bin12603.jpg
# ./DataSet1/Bin37928.jpg
# ./DataSet1/Bin45079.jpg
# ./DataSet1/Bin27728.jpg
# ./DataSet1/Bin19617.jpg
# ./DataSet1/Bin18283.jpg
# ./DataSet1/Bin23584.jpg
# ./DataSet1/Bin2020.jpg
# ./DataSet1/Bin25855.jpg
# ./DataSet1/Bin12462.jpg
# ./DataSet1/Bin49.jpg
# ./DataSet1/Bin13227.jpg
# ./DataSet1/Bin32157.jpg
# ./DataSet1/Bin19866.jpg
# ./DataSet1/Bin24913.jpg
# ./DataSet1/Bin17456.jpg
# ./DataSet1/Bin14427.jpg
# ./DataSet1/Bin8322.jpg
# ./DataSet1/Bin44878.jpg
# ./DataSet1/Bin5848.jpg
# ./DataSet1/Bin8723.jpg
# ./DataSet1/Bin24226.jpg
# ./DataSet1/Bin37964.jpg
# ./DataSet1/Bin24390.jpg
# ./DataSet1/Bin7012.jpg
# ./DataSet1/Bin22111.jpg
# ./DataSet1/Bin47059.jpg
# ./DataSet1/Bin34748.jpg
# ./DataSet1/Bin709.jpg
# ./DataSet1/Bin12335.jpg
# ./DataSet1/Bin20971.jpg
# ./DataSet1/Bin14205.jpg
# ./DataSet1/Bin41253.jpg
# ./DataSet1/Bin10549.jpg
# ./DataSet1/Bin29530.jpg
# ./DataSet1/Bin13695.jpg
# ./DataSet1/Bin28268.jpg
# ./DataSet1/Bin45396.jpg
# ./DataSet1/Bin49351.jpg
# ./DataSet1/Bin17135.jpg
# ./DataSet1/Bin28905.jpg
# ./DataSet1/Bin9465.jpg
# ./DataSet1/Bin9503.jpg
# ./DataSet1/Bin19435.jpg
# ./DataSet1/Bin25407.jpg
# ./DataSet1/Bin30737.jpg
# ./DataSet1/Bin28229.jpg
# ./DataSet1/Bin13796.jpg
# ./DataSet1/Bin39350.jpg
# ./DataSet1/Bin18728.jpg
# ./DataSet1/Bin45203.jpg
# ./DataSet1/Bin32309.jpg
# ./DataSet1/Bin18712.jpg
# ./DataSet1/Bin17036.jpg
# ./DataSet1/Bin17773.jpg
# ./DataSet1/Bin46027.jpg
# ./DataSet1/Bin41444.jpg
# ./DataSet1/Bin8324.jpg
# ./DataSet1/Bin42181.jpg
# ./DataSet1/Bin20535.jpg
# ./DataSet1/Bin47426.jpg
# ./DataSet1/Bin48990.jpg
# ./DataSet1/Bin24166.jpg
# ./DataSet1/Bin11284.jpg
# ./DataSet1/Bin12956.jpg
# ./DataSet1/Bin46839.jpg
# ./DataSet1/Bin38886.jpg
# ./DataSet1/Bin17583.jpg
# ./DataSet1/Bin6066.jpg
# ./DataSet1/Bin46630.jpg
# ./DataSet1/Bin33236.jpg
# ./DataSet1/Bin12030.jpg
# ./DataSet1/Bin35118.jpg
# ./DataSet1/Bin15706.jpg
# ./DataSet1/Bin5518.jpg
# ./DataSet1/Bin28471.jpg
# ./DataSet1/Bin2062.jpg
# ./DataSet1/Bin24592.jpg
# ./DataSet1/Bin8445.jpg
# ./DataSet1/Bin23885.jpg
# ./DataSet1/Bin1398.jpg
# ./DataSet1/Bin23309.jpg
# ./DataSet1/Bin8424.jpg
# ./DataSet1/Bin16992.jpg
# ./DataSet1/Bin21990.jpg
# ./DataSet1/Bin15859.jpg
# ./DataSet1/Bin28537.jpg
# ./DataSet1/Bin21436.jpg
# ./DataSet1/Bin26264.jpg
# ./DataSet1/Bin1406.jpg
# ./DataSet1/Bin39360.jpg
# ./DataSet1/Bin34519.jpg
# ./DataSet1/Bin41196.jpg
# ./DataSet1/Bin6095.jpg
# ./DataSet1/Bin31254.jpg
# ./DataSet1/Bin27064.jpg
# ./DataSet1/Bin33411.jpg
# ./DataSet1/Bin31713.jpg
# ./DataSet1/Bin2395.jpg
# ./DataSet1/Bin43146.jpg
# ./DataSet1/Bin49275.jpg
# ./DataSet1/Bin11431.jpg
# ./DataSet1/Bin44785.jpg
# ./DataSet1/Bin2832.jpg
# ./DataSet1/Bin45357.jpg
# ./DataSet1/Bin16620.jpg
# ./DataSet1/Bin45573.jpg
# ./DataSet1/Bin18326.jpg
# ./DataSet1/Bin14142.jpg
# ./DataSet1/Bin34426.jpg
# ./DataSet1/Bin17604.jpg
# ./DataSet1/Bin1512.jpg
# ./DataSet1/Bin24049.jpg
# ./DataSet1/Bin16131.jpg
# ./DataSet1/Bin12472.jpg
# ./DataSet1/Bin36387.jpg
# ./DataSet1/Bin7201.jpg
# ./DataSet1/Bin47454.jpg
# ./DataSet1/Bin2617.jpg
# ./DataSet1/Bin34700.jpg
# ./DataSet1/Bin3985.jpg
# ./DataSet1/Bin40435.jpg
# ./DataSet1/Bin42307.jpg
# ./DataSet1/Bin29414.jpg
# ./DataSet1/Bin17385.jpg
# ./DataSet1/Bin20847.jpg
# ./DataSet1/Bin18299.jpg
# ./DataSet1/Bin10365.jpg
# ./DataSet1/Bin48212.jpg
# ./DataSet1/Bin37414.jpg
# ./DataSet1/Bin31870.jpg
# ./DataSet1/Bin8678.jpg
# ./DataSet1/Bin25546.jpg
# ./DataSet1/Bin37767.jpg
# ./DataSet1/Bin14118.jpg
# ./DataSet1/Bin48617.jpg
# ./DataSet1/Bin18571.jpg
# ./DataSet1/Bin13904.jpg
# ./DataSet1/Bin9440.jpg
# ./DataSet1/Bin1884.jpg
# ./DataSet1/Bin19433.jpg
# ./DataSet1/Bin41241.jpg
# ./DataSet1/Bin24237.jpg
# ./DataSet1/Bin20371.jpg
# ./DataSet1/Bin46435.jpg
# ./DataSet1/Bin20942.jpg
# ./DataSet1/Bin38720.jpg
# ./DataSet1/Bin21882.jpg
# ./DataSet1/Bin36341.jpg
# ./DataSet1/Bin27228.jpg
# ./DataSet1/Bin24719.jpg
# ./DataSet1/Bin15761.jpg
# ./DataSet1/Bin24346.jpg
# ./DataSet1/Bin3674.jpg
# ./DataSet1/Bin40237.jpg
# ./DataSet1/Bin38493.jpg
# ./DataSet1/Bin48459.jpg
# ./DataSet1/Bin4155.jpg
# ./DataSet1/Bin43021.jpg
# ./DataSet1/Bin3927.jpg
# ./DataSet1/Bin7583.jpg
# ./DataSet1/Bin31919.jpg
# ./DataSet1/Bin9044.jpg
# ./DataSet1/Bin441.jpg
# ./DataSet1/Bin19729.jpg
# ./DataSet1/Bin34809.jpg
# ./DataSet1/Bin27266.jpg
# ./DataSet1/Bin29938.jpg
# ./DataSet1/Bin38002.jpg
# ./DataSet1/Bin9129.jpg
# ./DataSet1/Bin27329.jpg
# ./DataSet1/Bin3724.jpg
# ./DataSet1/Bin32449.jpg
# ./DataSet1/Bin26049.jpg
# ./DataSet1/Bin27797.jpg
# ./DataSet1/Bin8332.jpg
# ./DataSet1/Bin14980.jpg
# ./DataSet1/Bin44167.jpg
# ./DataSet1/Bin21138.jpg
# ./DataSet1/Bin13249.jpg
# ./DataSet1/Bin18723.jpg
# ./DataSet1/Bin21267.jpg
# ./DataSet1/Bin39151.jpg
# ./DataSet1/Bin36694.jpg
# ./DataSet1/Bin9274.jpg
# ./DataSet1/Bin1475.jpg
# ./DataSet1/Bin30672.jpg
# ./DataSet1/Bin7030.jpg
# ./DataSet1/Bin21821.jpg
# ./DataSet1/Bin33424.jpg
# ./DataSet1/Bin30334.jpg
# ./DataSet1/Bin18094.jpg
# ./DataSet1/Bin9989.jpg
# ./DataSet1/Bin29243.jpg
# ./DataSet1/Bin8744.jpg
# ./DataSet1/Bin9817.jpg
# ./DataSet1/Bin32320.jpg
# ./DataSet1/Bin23428.jpg
# ./DataSet1/Bin43668.jpg
# ./DataSet1/Bin15155.jpg
# ./DataSet1/Bin39367.jpg
# ./DataSet1/Bin40496.jpg
# ./DataSet1/Bin25763.jpg
# ./DataSet1/Bin31578.jpg
# ./DataSet1/Bin12259.jpg
# ./DataSet1/Bin21049.jpg
# ./DataSet1/Bin49407.jpg
# ./DataSet1/Bin23597.jpg
# ./DataSet1/Bin27180.jpg
# ./DataSet1/Bin37978.jpg
# ./DataSet1/Bin8863.jpg
# ./DataSet1/Bin14933.jpg
# ./DataSet1/Bin24170.jpg
# ./DataSet1/Bin20592.jpg
# ./DataSet1/Bin49535.jpg
# ./DataSet1/Bin39134.jpg
# ./DataSet1/Bin27492.jpg
# ./DataSet1/Bin29937.jpg
# ./DataSet1/Bin7939.jpg
# ./DataSet1/Bin37163.jpg
# ./DataSet1/Bin26561.jpg
# ./DataSet1/Bin31880.jpg
# ./DataSet1/Bin40240.jpg
# ./DataSet1/Bin32886.jpg
# ./DataSet1/Bin39440.jpg
# ./DataSet1/Bin32503.jpg
# ./DataSet1/Bin13509.jpg
# ./DataSet1/Bin42461.jpg
# ./DataSet1/Bin33286.jpg
# ./DataSet1/Bin6822.jpg
# ./DataSet1/Bin41548.jpg
# ./DataSet1/Bin43466.jpg
# ./DataSet1/Bin6819.jpg
# ./DataSet1/Bin12774.jpg
# ./DataSet1/Bin29576.jpg
# ./DataSet1/Bin18842.jpg
# ./DataSet1/Bin40479.jpg
# ./DataSet1/Bin43976.jpg
# ./DataSet1/Bin10029.jpg
# ./DataSet1/Bin2202.jpg
# ./DataSet1/Bin49691.jpg
# ./DataSet1/Bin42687.jpg
# ./DataSet1/Bin12837.jpg
# ./DataSet1/Bin17584.jpg
# ./DataSet1/Bin41563.jpg
# ./DataSet1/Bin35242.jpg
# ./DataSet1/Bin15717.jpg
# ./DataSet1/Bin20097.jpg
# ./DataSet1/Bin662.jpg
# ./DataSet1/Bin44503.jpg
# ./DataSet1/Bin47723.jpg
# ./DataSet1/Bin15443.jpg
# ./DataSet1/Bin41249.jpg
# ./DataSet1/Bin29622.jpg
# ./DataSet1/Bin32303.jpg
# ./DataSet1/Bin10216.jpg
# ./DataSet1/Bin38581.jpg
# ./DataSet1/Bin12127.jpg
# ./DataSet1/Bin28259.jpg
# ./DataSet1/Bin32165.jpg
# ./DataSet1/Bin34214.jpg
# ./DataSet1/Bin25066.jpg
# ./DataSet1/Bin48865.jpg
# ./DataSet1/Bin47675.jpg
# ./DataSet1/Bin37820.jpg
# ./DataSet1/Bin44669.jpg
# ./DataSet1/Bin34350.jpg
# ./DataSet1/Bin2499.jpg
# ./DataSet1/Bin27899.jpg
# ./DataSet1/Bin32380.jpg
# ./DataSet1/Bin22270.jpg
# ./DataSet1/Bin8591.jpg
# ./DataSet1/Bin2738.jpg
# ./DataSet1/Bin6673.jpg
# ./DataSet1/Bin48897.jpg
# ./DataSet1/Bin20338.jpg
# ./DataSet1/Bin47296.jpg
# ./DataSet1/Bin41336.jpg
# ./DataSet1/Bin41396.jpg
# ./DataSet1/Bin27666.jpg
# ./DataSet1/Bin32178.jpg
# ./DataSet1/Bin11387.jpg
# ./DataSet1/Bin42833.jpg
# ./DataSet1/Bin324.jpg
# ./DataSet1/Bin34482.jpg
# ./DataSet1/Bin37619.jpg
# ./DataSet1/Bin28836.jpg
# ./DataSet1/Bin22116.jpg
# ./DataSet1/Bin37369.jpg
# ./DataSet1/Bin17301.jpg
# ./DataSet1/Bin13439.jpg
# ./DataSet1/Bin35689.jpg
# ./DataSet1/Bin37403.jpg
# ./DataSet1/Bin40698.jpg
# ./DataSet1/Bin18140.jpg
# ./DataSet1/Bin47802.jpg
# ./DataSet1/Bin36668.jpg
# ./DataSet1/Bin36559.jpg
# ./DataSet1/Bin16461.jpg
# ./DataSet1/Bin1827.jpg
# ./DataSet1/Bin6605.jpg
# ./DataSet1/Bin33738.jpg
# ./DataSet1/Bin12669.jpg
# ./DataSet1/Bin39598.jpg
# ./DataSet1/Bin45543.jpg
# ./DataSet1/Bin9481.jpg
# ./DataSet1/Bin6753.jpg
# ./DataSet1/Bin22756.jpg
# ./DataSet1/Bin75.jpg
# ./DataSet1/Bin8719.jpg
# ./DataSet1/Bin18076.jpg
# ./DataSet1/Bin4584.jpg
# ./DataSet1/Bin28567.jpg
# ./DataSet1/Bin11185.jpg
# ./DataSet1/Bin38064.jpg
# ./DataSet1/Bin41701.jpg
# ./DataSet1/Bin48742.jpg
# ./DataSet1/Bin6363.jpg
# ./DataSet1/Bin36421.jpg
# ./DataSet1/Bin45358.jpg
# ./DataSet1/Bin35200.jpg
# ./DataSet1/Bin35649.jpg
# ./DataSet1/Bin15548.jpg
# ./DataSet1/Bin17629.jpg
# ./DataSet1/Bin11654.jpg
# ./DataSet1/Bin40418.jpg
# ./DataSet1/Bin31525.jpg
# ./DataSet1/Bin37292.jpg
# ./DataSet1/Bin18572.jpg
# ./DataSet1/Bin46322.jpg
# ./DataSet1/Bin3701.jpg
# ./DataSet1/Bin44273.jpg
# ./DataSet1/Bin18849.jpg
# ./DataSet1/Bin43982.jpg
# ./DataSet1/Bin10293.jpg
# ./DataSet1/Bin25155.jpg
# ./DataSet1/Bin9383.jpg
# ./DataSet1/Bin45812.jpg
# ./DataSet1/Bin37198.jpg
# ./DataSet1/Bin13882.jpg
# ./DataSet1/Bin4314.jpg
# ./DataSet1/Bin37725.jpg
# ./DataSet1/Bin7895.jpg
# ./DataSet1/Bin4078.jpg
# ./DataSet1/Bin23201.jpg
# ./DataSet1/Bin40346.jpg
# ./DataSet1/Bin4446.jpg
# ./DataSet1/Bin6836.jpg
# ./DataSet1/Bin35738.jpg
# ./DataSet1/Bin44799.jpg
# ./DataSet1/Bin2357.jpg
# ./DataSet1/Bin21166.jpg
# ./DataSet1/Bin16778.jpg
# ./DataSet1/Bin47441.jpg
# ./DataSet1/Bin12659.jpg
# ./DataSet1/Bin38001.jpg
# ./DataSet1/Bin24229.jpg
# ./DataSet1/Bin38006.jpg
# ./DataSet1/Bin7492.jpg
# ./DataSet1/Bin32412.jpg
# ./DataSet1/Bin9856.jpg
# ./DataSet1/Bin8309.jpg
# ./DataSet1/Bin14638.jpg
# ./DataSet1/Bin10580.jpg
# ./DataSet1/Bin25703.jpg
# ./DataSet1/Bin13795.jpg
# ./DataSet1/Bin38702.jpg
# ./DataSet1/Bin31927.jpg
# ./DataSet1/Bin9047.jpg
# ./DataSet1/Bin47939.jpg
# ./DataSet1/Bin20126.jpg
# ./DataSet1/Bin26766.jpg
# ./DataSet1/Bin3076.jpg
# ./DataSet1/Bin43975.jpg
# ./DataSet1/Bin35861.jpg
# ./DataSet1/Bin33313.jpg
# ./DataSet1/Bin29620.jpg
# ./DataSet1/Bin11323.jpg
# ./DataSet1/Bin14836.jpg
# ./DataSet1/Bin46866.jpg
# ./DataSet1/Bin34839.jpg
# ./DataSet1/Bin43614.jpg
# ./DataSet1/Bin38731.jpg
# ./DataSet1/Bin31273.jpg
# ./DataSet1/Bin36213.jpg
# ./DataSet1/Bin44686.jpg
# ./DataSet1/Bin777.jpg
# ./DataSet1/Bin29653.jpg
# ./DataSet1/Bin21590.jpg
# ./DataSet1/Bin15417.jpg
# ./DataSet1/Bin32006.jpg
# ./DataSet1/Bin6199.jpg
# ./DataSet1/Bin1230.jpg
# ./DataSet1/Bin14301.jpg
# ./DataSet1/Bin46266.jpg
# ./DataSet1/Bin17714.jpg
# ./DataSet1/Bin23707.jpg
# ./DataSet1/Bin28737.jpg
# ./DataSet1/Bin48715.jpg
# ./DataSet1/Bin29147.jpg
# ./DataSet1/Bin9228.jpg
# ./DataSet1/Bin44776.jpg
# ./DataSet1/Bin34684.jpg
# ./DataSet1/Bin32443.jpg
# ./DataSet1/Bin16516.jpg
# ./DataSet1/Bin12892.jpg
# ./DataSet1/Bin36378.jpg
# ./DataSet1/Bin15171.jpg
# ./DataSet1/Bin17989.jpg
# ./DataSet1/Bin29145.jpg
# ./DataSet1/Bin45777.jpg
# ./DataSet1/Bin32895.jpg
# ./DataSet1/Bin45973.jpg
# ./DataSet1/Bin265.jpg
# ./DataSet1/Bin9172.jpg
# ./DataSet1/Bin15698.jpg
# ./DataSet1/Bin18971.jpg
# ./DataSet1/Bin31684.jpg
# ./DataSet1/Bin36440.jpg
# ./DataSet1/Bin36760.jpg
# ./DataSet1/Bin37459.jpg
# ./DataSet1/Bin38545.jpg
# ./DataSet1/Bin7492.jpg
# ./DataSet1/Bin2523.jpg
# ./DataSet1/Bin20028.jpg
# ./DataSet1/Bin35140.jpg
# ./DataSet1/Bin15465.jpg
# ./DataSet1/Bin17813.jpg
# ./DataSet1/Bin19516.jpg
# ./DataSet1/Bin26397.jpg
# ./DataSet1/Bin13797.jpg
# ./DataSet1/Bin18880.jpg
# ./DataSet1/Bin3957.jpg
# ./DataSet1/Bin25231.jpg
# ./DataSet1/Bin18431.jpg
# ./DataSet1/Bin40361.jpg
# ./DataSet1/Bin7552.jpg
# ./DataSet1/Bin24959.jpg
# ./DataSet1/Bin21324.jpg
# ./DataSet1/Bin2429.jpg
# ./DataSet1/Bin5650.jpg
# ./DataSet1/Bin13274.jpg
# ./DataSet1/Bin21615.jpg
# ./DataSet1/Bin48922.jpg
# ./DataSet1/Bin35035.jpg
# ./DataSet1/Bin40444.jpg
# ./DataSet1/Bin1867.jpg
# ./DataSet1/Bin25625.jpg
# ./DataSet1/Bin39892.jpg
# ./DataSet1/Bin32647.jpg
# ./DataSet1/Bin19731.jpg
# ./DataSet1/Bin38378.jpg
# ./DataSet1/Bin44784.jpg
# ./DataSet1/Bin4931.jpg
# ./DataSet1/Bin20525.jpg
# ./DataSet1/Bin42159.jpg
# ./DataSet1/Bin38980.jpg
# ./DataSet1/Bin46444.jpg
# ./DataSet1/Bin3663.jpg
# ./DataSet1/Bin25945.jpg
# ./DataSet1/Bin12644.jpg
# ./DataSet1/Bin37668.jpg
# ./DataSet1/Bin11289.jpg
# ./DataSet1/Bin30091.jpg
# ./DataSet1/Bin42343.jpg
# ./DataSet1/Bin26653.jpg
# ./DataSet1/Bin19830.jpg
# ./DataSet1/Bin31368.jpg
# ./DataSet1/Bin40774.jpg
# ./DataSet1/Bin20240.jpg
# ./DataSet1/Bin20462.jpg
# ./DataSet1/Bin31658.jpg
# ./DataSet1/Bin37414.jpg
# ./DataSet1/Bin20566.jpg
# ./DataSet1/Bin5577.jpg
# ./DataSet1/Bin21341.jpg
# ./DataSet1/Bin35184.jpg
# ./DataSet1/Bin17083.jpg
# ./DataSet1/Bin21485.jpg
# ./DataSet1/Bin36382.jpg
# ./DataSet1/Bin12555.jpg
# ./DataSet1/Bin25668.jpg
# ./DataSet1/Bin7253.jpg
# ./DataSet1/Bin23112.jpg
# ./DataSet1/Bin4755.jpg
# ./DataSet1/Bin3924.jpg
# ./DataSet1/Bin22986.jpg
# ./DataSet1/Bin17116.jpg
# ./DataSet1/Bin36671.jpg
# ./DataSet1/Bin9092.jpg
# ./DataSet1/Bin17381.jpg
# ./DataSet1/Bin37658.jpg
# ./DataSet1/Bin35911.jpg
# ./DataSet1/Bin47250.jpg
# ./DataSet1/Bin4535.jpg
# ./DataSet1/Bin5565.jpg
# ./DataSet1/Bin37908.jpg
# ./DataSet1/Bin41210.jpg
# ./DataSet1/Bin14190.jpg
# ./DataSet1/Bin28518.jpg
# ./DataSet1/Bin39648.jpg
# ./DataSet1/Bin47371.jpg
# ./DataSet1/Bin4794.jpg
# ./DataSet1/Bin9308.jpg
# ./DataSet1/Bin47237.jpg
# ./DataSet1/Bin45276.jpg
# ./DataSet1/Bin20528.jpg
# ./DataSet1/Bin6828.jpg
# ./DataSet1/Bin32269.jpg
# ./DataSet1/Bin48955.jpg
# ./DataSet1/Bin41093.jpg
# ./DataSet1/Bin38590.jpg
# ./DataSet1/Bin32315.jpg
# ./DataSet1/Bin10282.jpg
# ./DataSet1/Bin15033.jpg
# ./DataSet1/Bin5900.jpg
# ./DataSet1/Bin39001.jpg
# ./DataSet1/Bin2007.jpg
# ./DataSet1/Bin38678.jpg
# ./DataSet1/Bin11881.jpg
# ./DataSet1/Bin8612.jpg
# ./DataSet1/Bin21320.jpg
# ./DataSet1/Bin31109.jpg
# ./DataSet1/Bin6813.jpg
# ./DataSet1/Bin18681.jpg
# ./DataSet1/Bin17039.jpg
# ./DataSet1/Bin7976.jpg
# ./DataSet1/Bin37272.jpg
# ./DataSet1/Bin1234.jpg
# ./DataSet1/Bin28259.jpg
# ./DataSet1/Bin31053.jpg
# ./DataSet1/Bin34604.jpg
# ./DataSet1/Bin18494.jpg
# ./DataSet1/Bin49519.jpg
# ./DataSet1/Bin39023.jpg
# ./DataSet1/Bin6807.jpg
# ./DataSet1/Bin37684.jpg
# ./DataSet1/Bin24546.jpg
# ./DataSet1/Bin10092.jpg
# ./DataSet1/Bin40088.jpg
# ./DataSet1/Bin27633.jpg
# ./DataSet1/Bin31823.jpg
# ./DataSet1/Bin3421.jpg
# ./DataSet1/Bin16006.jpg
# ./DataSet1/Bin11887.jpg
# ./DataSet1/Bin5798.jpg
# ./DataSet1/Bin37883.jpg
# ./DataSet1/Bin26660.jpg
# ./DataSet1/Bin34575.jpg
# ./DataSet1/Bin9621.jpg
# ./DataSet1/Bin29527.jpg
# ./DataSet1/Bin3495.jpg
# ./DataSet1/Bin49228.jpg
# ./DataSet1/Bin11582.jpg
# ./DataSet1/Bin14205.jpg
# ./DataSet1/Bin13642.jpg
# ./DataSet1/Bin8057.jpg
# ./DataSet1/Bin36265.jpg
# ./DataSet1/Bin42027.jpg
# ./DataSet1/Bin14364.jpg
# ./DataSet1/Bin48379.jpg
# ./DataSet1/Bin19637.jpg
# ./DataSet1/Bin18402.jpg
# ./DataSet1/Bin2805.jpg
# ./DataSet1/Bin15372.jpg
# ./DataSet1/Bin2824.jpg
# ./DataSet1/Bin37171.jpg
# ./DataSet1/Bin22438.jpg
# ./DataSet1/Bin29665.jpg
# ./DataSet1/Bin12353.jpg
# ./DataSet1/Bin23604.jpg
# ./DataSet1/Bin15011.jpg
# ./DataSet1/Bin34787.jpg
# ./DataSet1/Bin18122.jpg
# ./DataSet1/Bin564.jpg
# ./DataSet1/Bin32957.jpg
# ./DataSet1/Bin3484.jpg
# ./DataSet1/Bin45318.jpg
# ./DataSet1/Bin25889.jpg
# ./DataSet1/Bin16744.jpg
# ./DataSet1/Bin20225.jpg
# ./DataSet1/Bin26233.jpg
# ./DataSet1/Bin36063.jpg
# ./DataSet1/Bin44737.jpg
# ./DataSet1/Bin29876.jpg
# ./DataSet1/Bin11641.jpg
# ./DataSet1/Bin7296.jpg
# ./DataSet1/Bin22235.jpg
# ./DataSet1/Bin13607.jpg
# ./DataSet1/Bin8079.jpg
# ./DataSet1/Bin29156.jpg
# ./DataSet1/Bin23956.jpg
# ./DataSet1/Bin42005.jpg
# ./DataSet1/Bin20533.jpg
# ./DataSet1/Bin31743.jpg
# ./DataSet1/Bin49824.jpg
# ./DataSet1/Bin46021.jpg
# ./DataSet1/Bin26271.jpg
# ./DataSet1/Bin8016.jpg
# ./DataSet1/Bin37506.jpg
# ./DataSet1/Bin8694.jpg
# ./DataSet1/Bin21890.jpg
# ./DataSet1/Bin43696.jpg
# ./DataSet1/Bin11558.jpg
# ./DataSet1/Bin18683.jpg
# ./DataSet1/Bin29887.jpg
# ./DataSet1/Bin33975.jpg
# ./DataSet1/Bin23553.jpg
# ./DataSet1/Bin25766.jpg
# ./DataSet1/Bin41141.jpg
# ./DataSet1/Bin6304.jpg
# ./DataSet1/Bin16990.jpg
# ./DataSet1/Bin12903.jpg
# ./DataSet1/Bin14145.jpg
# ./DataSet1/Bin2124.jpg
# ./DataSet1/Bin41482.jpg
# ./DataSet1/Bin28938.jpg
# ./DataSet1/Bin21509.jpg
# ./DataSet1/Bin31053.jpg
# ./DataSet1/Bin39589.jpg
# ./DataSet1/Bin39258.jpg
# ./DataSet1/Bin32445.jpg
# ./DataSet1/Bin44468.jpg
# ./DataSet1/Bin35091.jpg
# ./DataSet1/Bin6511.jpg
# ./DataSet1/Bin5382.jpg
# ./DataSet1/Bin5349.jpg
# ./DataSet1/Bin14987.jpg
# ./DataSet1/Bin15754.jpg
# ./DataSet1/Bin14216.jpg
# ./DataSet1/Bin25520.jpg
# ./DataSet1/Bin59.jpg
# ./DataSet1/Bin18703.jpg
# ./DataSet1/Bin20395.jpg
# ./DataSet1/Bin27348.jpg
# ./DataSet1/Bin26232.jpg
# ./DataSet1/Bin43778.jpg
# ./DataSet1/Bin22769.jpg
# ./DataSet1/Bin15578.jpg
# ./DataSet1/Bin7228.jpg
# ./DataSet1/Bin19444.jpg
# ./DataSet1/Bin15432.jpg
# ./DataSet1/Bin7626.jpg
# ./DataSet1/Bin36607.jpg
# ./DataSet1/Bin5116.jpg
# ./DataSet1/Bin28669.jpg
# ./DataSet1/Bin42606.jpg
# ./DataSet1/Bin4815.jpg
# ./DataSet1/Bin33978.jpg
# ./DataSet1/Bin44689.jpg
# ./DataSet1/Bin22625.jpg
# ./DataSet1/Bin24698.jpg
# ./DataSet1/Bin33907.jpg
# ./DataSet1/Bin32274.jpg
# ./DataSet1/Bin42152.jpg
# ./DataSet1/Bin12693.jpg
# ./DataSet1/Bin38117.jpg
# ./DataSet1/Bin12537.jpg
# ./DataSet1/Bin10784.jpg
# ./DataSet1/Bin47533.jpg
# ./DataSet1/Bin45439.jpg
# ./DataSet1/Bin24847.jpg
# ./DataSet1/Bin41155.jpg
# ./DataSet1/Bin8194.jpg
# ./DataSet1/Bin20449.jpg
# ./DataSet1/Bin19030.jpg
# ./DataSet1/Bin22665.jpg
# ./DataSet1/Bin22457.jpg
# ./DataSet1/Bin43084.jpg
# ./DataSet1/Bin43754.jpg
# ./DataSet1/Bin25569.jpg
# ./DataSet1/Bin4622.jpg
# ./DataSet1/Bin3556.jpg
# ./DataSet1/Bin5702.jpg
# ./DataSet1/Bin38581.jpg
# ./DataSet1/Bin20833.jpg
# ./DataSet1/Bin31748.jpg
# ./DataSet1/Bin3231.jpg
# ./DataSet1/Bin44752.jpg
# ./DataSet1/Bin6033.jpg
# ./DataSet1/Bin14351.jpg
# ./DataSet1/Bin39913.jpg
# ./DataSet1/Bin38783.jpg
# ./DataSet1/Bin12007.jpg
# ./DataSet1/Bin5917.jpg
# ./DataSet1/Bin25447.jpg
# ./DataSet1/Bin26321.jpg
# ./DataSet1/Bin26753.jpg
# ./DataSet1/Bin24102.jpg
# ./DataSet1/Bin10916.jpg
# ./DataSet1/Bin35026.jpg
# ./DataSet1/Bin39752.jpg
# ./DataSet1/Bin10247.jpg
# ./DataSet1/Bin45468.jpg
# ./DataSet1/Bin13117.jpg
# ./DataSet1/Bin5968.jpg
# ./DataSet1/Bin3605.jpg
# ./DataSet1/Bin5094.jpg
# ./DataSet1/Bin10477.jpg
# ./DataSet1/Bin27620.jpg
# ./DataSet1/Bin23912.jpg
# ./DataSet1/Bin31611.jpg
# ./DataSet1/Bin472.jpg
# ./DataSet1/Bin23540.jpg
# ./DataSet1/Bin35190.jpg
# ./DataSet1/Bin41502.jpg
# ./DataSet1/Bin12272.jpg
# ./DataSet1/Bin49795.jpg
# ./DataSet1/Bin14325.jpg
# ./DataSet1/Bin18160.jpg
# ./DataSet1/Bin7567.jpg
# ./DataSet1/Bin39911.jpg
# ./DataSet1/Bin2979.jpg
# ./DataSet1/Bin10183.jpg
# ./DataSet1/Bin21890.jpg
# ./DataSet1/Bin10613.jpg
# ./DataSet1/Bin16389.jpg
# ./DataSet1/Bin45607.jpg
# ./DataSet1/Bin49173.jpg
# ./DataSet1/Bin37297.jpg
# ./DataSet1/Bin37092.jpg
# ./DataSet1/Bin781.jpg
# ./DataSet1/Bin39767.jpg
# ...
# ./DataSet1/Bin40527.jpg
# ./DataSet1/Bin43370.jpg
# ./DataSet1/Bin47161.jpg
# ./DataSet1/Bin45159.jpg
# ./DataSet1/Bin16528.jpg
# ./DataSet1/Bin39239.jpg
# ./DataSet1/Bin40319.jpg
# ./DataSet1/Bin21914.jpg
# ./DataSet1/Bin23926.jpg
# ./DataSet1/Bin17367.jpg
# ./DataSet1/Bin29977.jpg
# ./DataSet1/Bin23122.jpg
# ./DataSet1/Bin30256.jpg
# ./DataSet1/Bin9971.jpg
# ./DataSet1/Bin13153.jpg
# ./DataSet1/Bin14470.jpg
# ./DataSet1/Bin46120.jpg
# ./DataSet1/Bin39788.jpg
# ./DataSet1/Bin14762.jpg
# ./DataSet1/Bin21931.jpg
# ./DataSet1/Bin337.jpg
# ./DataSet1/Bin36976.jpg
# ./DataSet1/Bin21076.jpg
# ./DataSet1/Bin46598.jpg
# ./DataSet1/Bin25428.jpg
# ./DataSet1/Bin48940.jpg
# ./DataSet1/Bin32072.jpg
# ./DataSet1/Bin39234.jpg
# ./DataSet1/Bin43928.jpg
# ./DataSet1/Bin2507.jpg
# ./DataSet1/Bin29327.jpg
# ./DataSet1/Bin9125.jpg
# ./DataSet1/Bin29735.jpg
# ./DataSet1/Bin18940.jpg
# ./DataSet1/Bin15156.jpg
# ./DataSet1/Bin23185.jpg
# ./DataSet1/Bin12871.jpg
# ./DataSet1/Bin11440.jpg
# ./DataSet1/Bin13072.jpg
# ./DataSet1/Bin21592.jpg
# ./DataSet1/Bin36551.jpg
# ./DataSet1/Bin833.jpg
# ./DataSet1/Bin22983.jpg
# ./DataSet1/Bin33087.jpg
# ./DataSet1/Bin40015.jpg
# ./DataSet1/Bin21740.jpg
# ./DataSet1/Bin13455.jpg
# ./DataSet1/Bin10738.jpg
# ./DataSet1/Bin15111.jpg
# ./DataSet1/Bin43710.jpg
# ./DataSet1/Bin4286.jpg
# ./DataSet1/Bin16950.jpg
# ./DataSet1/Bin25493.jpg
# ./DataSet1/Bin21726.jpg
# ./DataSet1/Bin34043.jpg
# ./DataSet1/Bin6675.jpg
# ./DataSet1/Bin453.jpg
# ./DataSet1/Bin35140.jpg
# ./DataSet1/Bin38007.jpg
# ./DataSet1/Bin6050.jpg
# ./DataSet1/Bin22327.jpg
# ./DataSet1/Bin10090.jpg
# ./DataSet1/Bin33586.jpg
# ./DataSet1/Bin44692.jpg
# ./DataSet1/Bin44233.jpg
# ./DataSet1/Bin18385.jpg
# ./DataSet1/Bin3932.jpg
# ./DataSet1/Bin7805.jpg
# ./DataSet1/Bin12735.jpg
# ./DataSet1/Bin13313.jpg
# ./DataSet1/Bin26707.jpg
# ./DataSet1/Bin46577.jpg
# ./DataSet1/Bin964.jpg
# ./DataSet1/Bin11968.jpg
# ./DataSet1/Bin457.jpg
# ./DataSet1/Bin48420.jpg
# ./DataSet1/Bin49989.jpg
# ./DataSet1/Bin10952.jpg
# ./DataSet1/Bin37433.jpg
# ./DataSet1/Bin17739.jpg
# ./DataSet1/Bin13091.jpg
# ./DataSet1/Bin45143.jpg
# ./DataSet1/Bin10554.jpg
# ./DataSet1/Bin8082.jpg
# ./DataSet1/Bin21432.jpg
# ./DataSet1/Bin11704.jpg
# ./DataSet1/Bin7548.jpg
# ./DataSet1/Bin35577.jpg
# ./DataSet1/Bin12624.jpg
# ./DataSet1/Bin8592.jpg
# ./DataSet1/Bin29113.jpg
# ./DataSet1/Bin28077.jpg
# ./DataSet1/Bin49820.jpg
# ./DataSet1/Bin48602.jpg
# ./DataSet1/Bin37697.jpg
# ./DataSet1/Bin36808.jpg
# ./DataSet1/Bin210.jpg
# ./DataSet1/Bin18826.jpg
# ./DataSet1/Bin34875.jpg
# ./DataSet1/Bin45082.jpg
# ./DataSet1/Bin15149.jpg
# ./DataSet1/Bin3764.jpg
# ./DataSet1/Bin19342.jpg
# ./DataSet1/Bin18098.jpg
# ./DataSet1/Bin6787.jpg
# ./DataSet1/Bin4634.jpg
# ./DataSet1/Bin32537.jpg
# ./DataSet1/Bin36205.jpg
# ./DataSet1/Bin21920.jpg
# ./DataSet1/Bin3614.jpg
# ./DataSet1/Bin37143.jpg
# ./DataSet1/Bin15760.jpg
# ./DataSet1/Bin45303.jpg
# ./DataSet1/Bin34177.jpg
# ./DataSet1/Bin2884.jpg
# ./DataSet1/Bin2368.jpg
# ./DataSet1/Bin817.jpg
# ./DataSet1/Bin3209.jpg
# ./DataSet1/Bin48626.jpg
# ./DataSet1/Bin36977.jpg
# ./DataSet1/Bin45330.jpg
# ./DataSet1/Bin21275.jpg
# ./DataSet1/Bin45841.jpg
# ./DataSet1/Bin14740.jpg
# ./DataSet1/Bin9285.jpg
# ./DataSet1/Bin4972.jpg
# ./DataSet1/Bin46284.jpg
# ./DataSet1/Bin13170.jpg
# ./DataSet1/Bin34851.jpg
# ./DataSet1/Bin21517.jpg
# ./DataSet1/Bin24628.jpg
# ./DataSet1/Bin3659.jpg
# ./DataSet1/Bin12944.jpg
# ./DataSet1/Bin40443.jpg
# ./DataSet1/Bin20742.jpg
# ./DataSet1/Bin27821.jpg
# ./DataSet1/Bin25325.jpg
# ./DataSet1/Bin8934.jpg
# ./DataSet1/Bin8980.jpg
# ./DataSet1/Bin3371.jpg
# ./DataSet1/Bin6562.jpg
# ./DataSet1/Bin48143.jpg
# ./DataSet1/Bin31528.jpg
# ./DataSet1/Bin28967.jpg
# ./DataSet1/Bin24014.jpg
# ./DataSet1/Bin35481.jpg
# ./DataSet1/Bin5364.jpg
# ./DataSet1/Bin45585.jpg
# ./DataSet1/Bin7329.jpg
# ./DataSet1/Bin34153.jpg
# ./DataSet1/Bin3767.jpg
# ./DataSet1/Bin25511.jpg
# ./DataSet1/Bin13027.jpg
# ./DataSet1/Bin48329.jpg
# ./DataSet1/Bin35579.jpg
# ./DataSet1/Bin43944.jpg
# ./DataSet1/Bin43664.jpg
# ./DataSet1/Bin27416.jpg
# ./DataSet1/Bin33972.jpg
# ./DataSet1/Bin4997.jpg
# ./DataSet1/Bin5070.jpg
# ./DataSet1/Bin34369.jpg
# ./DataSet1/Bin3062.jpg
# ./DataSet1/Bin33645.jpg
# ./DataSet1/Bin6279.jpg
# ./DataSet1/Bin19670.jpg
# ./DataSet1/Bin30219.jpg
# ./DataSet1/Bin43859.jpg
# ./DataSet1/Bin31974.jpg
# ./DataSet1/Bin24664.jpg
# ./DataSet1/Bin40085.jpg
# ./DataSet1/Bin2040.jpg
# ./DataSet1/Bin14303.jpg
# ./DataSet1/Bin17829.jpg
# ./DataSet1/Bin29245.jpg
# ./DataSet1/Bin19939.jpg
# ./DataSet1/Bin36054.jpg
# ./DataSet1/Bin39284.jpg
# ./DataSet1/Bin22683.jpg
# ./DataSet1/Bin14198.jpg
# ./DataSet1/Bin1508.jpg
# ./DataSet1/Bin47865.jpg
# ./DataSet1/Bin18579.jpg
# ./DataSet1/Bin23217.jpg
# ./DataSet1/Bin12719.jpg
# ./DataSet1/Bin10781.jpg
# ./DataSet1/Bin34713.jpg
# ./DataSet1/Bin17607.jpg
# ./DataSet1/Bin39284.jpg
# ./DataSet1/Bin12824.jpg
# ./DataSet1/Bin4999.jpg
# ./DataSet1/Bin25600.jpg
# ./DataSet1/Bin19906.jpg
# ./DataSet1/Bin795.jpg
# ./DataSet1/Bin25204.jpg
# ./DataSet1/Bin3370.jpg
# ./DataSet1/Bin33481.jpg
# ./DataSet1/Bin40594.jpg
# ./DataSet1/Bin31984.jpg
# ./DataSet1/Bin16216.jpg
# ./DataSet1/Bin17173.jpg
# ./DataSet1/Bin10264.jpg
# ./DataSet1/Bin3045.jpg
# ./DataSet1/Bin24647.jpg
# ./DataSet1/Bin9114.jpg
# ./DataSet1/Bin18274.jpg
# ./DataSet1/Bin42457.jpg
# ./DataSet1/Bin3587.jpg
# ./DataSet1/Bin46516.jpg
# ./DataSet1/Bin23862.jpg
# ./DataSet1/Bin40962.jpg
# ./DataSet1/Bin41745.jpg
# ./DataSet1/Bin48050.jpg
# ./DataSet1/Bin31435.jpg
# ./DataSet1/Bin42758.jpg
# ./DataSet1/Bin41814.jpg
# ./DataSet1/Bin10382.jpg
# ./DataSet1/Bin20785.jpg
# ./DataSet1/Bin8047.jpg
# ./DataSet1/Bin35237.jpg
# ./DataSet1/Bin6384.jpg
# ./DataSet1/Bin28682.jpg
# ./DataSet1/Bin10964.jpg
# ./DataSet1/Bin25663.jpg
# ./DataSet1/Bin27113.jpg
# ./DataSet1/Bin41693.jpg
# ./DataSet1/Bin48800.jpg
# ./DataSet1/Bin14340.jpg
# ./DataSet1/Bin46286.jpg
# ./DataSet1/Bin16111.jpg
# ./DataSet1/Bin39405.jpg
# ./DataSet1/Bin30161.jpg
# ./DataSet1/Bin30417.jpg
# ./DataSet1/Bin49093.jpg
# ./DataSet1/Bin1963.jpg
# ./DataSet1/Bin14431.jpg
# ./DataSet1/Bin45593.jpg
# ./DataSet1/Bin34864.jpg
# ./DataSet1/Bin19118.jpg
# ./DataSet1/Bin32443.jpg
# ./DataSet1/Bin35896.jpg
# ./DataSet1/Bin49125.jpg
# ./DataSet1/Bin337.jpg
# ./DataSet1/Bin46701.jpg
# ./DataSet1/Bin36731.jpg
# ./DataSet1/Bin21018.jpg
# ./DataSet1/Bin48783.jpg
# ./DataSet1/Bin38602.jpg
# ./DataSet1/Bin9456.jpg
# ./DataSet1/Bin5899.jpg
# ./DataSet1/Bin32176.jpg
# ./DataSet1/Bin28944.jpg
# ./DataSet1/Bin15758.jpg
# ./DataSet1/Bin49987.jpg
# ./DataSet1/Bin32.jpg
# ./DataSet1/Bin28472.jpg
# ./DataSet1/Bin40219.jpg
# ./DataSet1/Bin45584.jpg
# ./DataSet1/Bin27093.jpg
# ./DataSet1/Bin40380.jpg
# ./DataSet1/Bin14473.jpg
# ./DataSet1/Bin9779.jpg
# ./DataSet1/Bin44868.jpg
# ./DataSet1/Bin48767.jpg
# ./DataSet1/Bin44463.jpg
# ./DataSet1/Bin23273.jpg
# ./DataSet1/Bin41695.jpg
# ./DataSet1/Bin41318.jpg
# ./DataSet1/Bin30160.jpg
# ./DataSet1/Bin26688.jpg
# ./DataSet1/Bin39462.jpg
# ./DataSet1/Bin24906.jpg
# ./DataSet1/Bin18750.jpg
# ./DataSet1/Bin14644.jpg
# ./DataSet1/Bin9562.jpg
# ./DataSet1/Bin35083.jpg
# ./DataSet1/Bin22220.jpg
# ./DataSet1/Bin40737.jpg
# ./DataSet1/Bin11721.jpg
# ./DataSet1/Bin26374.jpg
# ./DataSet1/Bin12172.jpg
# ./DataSet1/Bin5194.jpg
# ./DataSet1/Bin38638.jpg
# ./DataSet1/Bin14479.jpg
# ./DataSet1/Bin34067.jpg
# ./DataSet1/Bin31120.jpg
# ./DataSet1/Bin27010.jpg
# ./DataSet1/Bin4329.jpg
# ./DataSet1/Bin17431.jpg
# ./DataSet1/Bin8918.jpg
# ./DataSet1/Bin20379.jpg
# ./DataSet1/Bin33543.jpg
# ./DataSet1/Bin13033.jpg
# ./DataSet1/Bin14029.jpg
# ./DataSet1/Bin26729.jpg
# ./DataSet1/Bin32465.jpg
# ./DataSet1/Bin5783.jpg
# ./DataSet1/Bin24087.jpg
# ./DataSet1/Bin33387.jpg
# ./DataSet1/Bin20704.jpg
# ./DataSet1/Bin42320.jpg
# ./DataSet1/Bin22829.jpg
# ./DataSet1/Bin20105.jpg
# ./DataSet1/Bin39914.jpg
# ./DataSet1/Bin42960.jpg
# ./DataSet1/Bin47923.jpg
# ./DataSet1/Bin27030.jpg
# ./DataSet1/Bin30920.jpg
# ./DataSet1/Bin9601.jpg
# ./DataSet1/Bin4630.jpg
# ./DataSet1/Bin15364.jpg
# ./DataSet1/Bin5520.jpg
# ./DataSet1/Bin20072.jpg
# ./DataSet1/Bin16810.jpg
# ./DataSet1/Bin42694.jpg
# ./DataSet1/Bin31621.jpg
# ./DataSet1/Bin47634.jpg
# ./DataSet1/Bin25685.jpg
# ./DataSet1/Bin39944.jpg
# ./DataSet1/Bin13355.jpg
# ./DataSet1/Bin33143.jpg
# ./DataSet1/Bin49518.jpg
# ./DataSet1/Bin45775.jpg
# ./DataSet1/Bin36431.jpg
# ./DataSet1/Bin43843.jpg
# ./DataSet1/Bin3232.jpg
# ./DataSet1/Bin19428.jpg
# ./DataSet1/Bin292.jpg
# ./DataSet1/Bin2455.jpg
# ./DataSet1/Bin47942.jpg
# ./DataSet1/Bin30324.jpg
# ./DataSet1/Bin16831.jpg
# ./DataSet1/Bin42054.jpg
# ./DataSet1/Bin976.jpg
# ./DataSet1/Bin13862.jpg
# ./DataSet1/Bin6782.jpg
# ./DataSet1/Bin11456.jpg
# ./DataSet1/Bin23721.jpg
# ./DataSet1/Bin23964.jpg
# ./DataSet1/Bin33130.jpg
# ./DataSet1/Bin6246.jpg
# ./DataSet1/Bin31649.jpg
# ./DataSet1/Bin3798.jpg
# ./DataSet1/Bin13742.jpg
# ./DataSet1/Bin7623.jpg
# ./DataSet1/Bin18283.jpg
# ./DataSet1/Bin25144.jpg
# ./DataSet1/Bin24484.jpg
# ./DataSet1/Bin3779.jpg
# ./DataSet1/Bin41963.jpg
# ./DataSet1/Bin47350.jpg
# ./DataSet1/Bin29277.jpg
# ./DataSet1/Bin6071.jpg
# ./DataSet1/Bin36020.jpg
# ./DataSet1/Bin35837.jpg
# ./DataSet1/Bin45625.jpg
# ./DataSet1/Bin7760.jpg
# ./DataSet1/Bin36205.jpg
# ./DataSet1/Bin42955.jpg
# ./DataSet1/Bin12197.jpg
# ./DataSet1/Bin12810.jpg
# ./DataSet1/Bin47269.jpg
# ./DataSet1/Bin6202.jpg
# ./DataSet1/Bin46909.jpg
# ./DataSet1/Bin35900.jpg
# ./DataSet1/Bin29776.jpg
# ./DataSet1/Bin45770.jpg
# ./DataSet1/Bin19777.jpg
# ./DataSet1/Bin27849.jpg
# ./DataSet1/Bin32221.jpg
# ./DataSet1/Bin5206.jpg
# ./DataSet1/Bin25855.jpg
# ./DataSet1/Bin43590.jpg
# ./DataSet1/Bin36147.jpg
# ./DataSet1/Bin7102.jpg
# ./DataSet1/Bin8916.jpg
# ./DataSet1/Bin28349.jpg
# ./DataSet1/Bin12163.jpg
# ./DataSet1/Bin6109.jpg
# ./DataSet1/Bin41408.jpg
# ./DataSet1/Bin8007.jpg
# ./DataSet1/Bin38908.jpg
# ./DataSet1/Bin44214.jpg
# ./DataSet1/Bin9815.jpg
# ./DataSet1/Bin46053.jpg
# ./DataSet1/Bin44186.jpg
# ./DataSet1/Bin42264.jpg
# ./DataSet1/Bin18815.jpg
# ./DataSet1/Bin35617.jpg
# ./DataSet1/Bin806.jpg
# ./DataSet1/Bin36492.jpg
# ./DataSet1/Bin25578.jpg
# ./DataSet1/Bin12696.jpg
# ./DataSet1/Bin45371.jpg
# ./DataSet1/Bin35109.jpg
# ./DataSet1/Bin42799.jpg
# ./DataSet1/Bin4122.jpg
# ./DataSet1/Bin31099.jpg
# ./DataSet1/Bin12471.jpg
# ./DataSet1/Bin26831.jpg
# ./DataSet1/Bin37907.jpg
# ./DataSet1/Bin35152.jpg
# ./DataSet1/Bin15179.jpg
# ./DataSet1/Bin49449.jpg
# ./DataSet1/Bin27677.jpg
# ./DataSet1/Bin3041.jpg
# ./DataSet1/Bin10602.jpg
# ./DataSet1/Bin32723.jpg
# ./DataSet1/Bin43918.jpg
# ./DataSet1/Bin45704.jpg
# ./DataSet1/Bin1261.jpg
# ./DataSet1/Bin30944.jpg
# ./DataSet1/Bin1222.jpg
# ./DataSet1/Bin36113.jpg
# ./DataSet1/Bin7008.jpg
# ./DataSet1/Bin36130.jpg
# ./DataSet1/Bin24522.jpg
# ./DataSet1/Bin3754.jpg
# ./DataSet1/Bin302.jpg
# ./DataSet1/Bin44507.jpg
# ./DataSet1/Bin25957.jpg
# ./DataSet1/Bin41185.jpg
# ./DataSet1/Bin18307.jpg
# ./DataSet1/Bin35732.jpg
# ./DataSet1/Bin41901.jpg
# ./DataSet1/Bin33523.jpg
# ./DataSet1/Bin23854.jpg
# ./DataSet1/Bin42032.jpg
# ./DataSet1/Bin20653.jpg
# ./DataSet1/Bin42945.jpg
# ./DataSet1/Bin1934.jpg
# ./DataSet1/Bin20683.jpg
# ./DataSet1/Bin20747.jpg
# ./DataSet1/Bin29091.jpg
# ./DataSet1/Bin12897.jpg
# ./DataSet1/Bin379.jpg
# ./DataSet1/Bin41355.jpg
# ./DataSet1/Bin1965.jpg
# ./DataSet1/Bin47134.jpg
# ./DataSet1/Bin11468.jpg
# ./DataSet1/Bin35543.jpg
# ./DataSet1/Bin13944.jpg
# ./DataSet1/Bin15807.jpg
# ./DataSet1/Bin17405.jpg
# ./DataSet1/Bin40274.jpg
# ./DataSet1/Bin3207.jpg
# ./DataSet1/Bin1949.jpg
# ./DataSet1/Bin18590.jpg
# ./DataSet1/Bin16512.jpg
# ./DataSet1/Bin28390.jpg
# ./DataSet1/Bin41307.jpg
# ./DataSet1/Bin36946.jpg
# ./DataSet1/Bin20065.jpg
# ./DataSet1/Bin8788.jpg
# ./DataSet1/Bin29045.jpg
# ./DataSet1/Bin47211.jpg
# ./DataSet1/Bin15051.jpg
# ./DataSet1/Bin26505.jpg
# ./DataSet1/Bin5474.jpg
# ./DataSet1/Bin4178.jpg
# ./DataSet1/Bin15710.jpg
# ./DataSet1/Bin43234.jpg
# ./DataSet1/Bin42022.jpg
# ./DataSet1/Bin30988.jpg
# ./DataSet1/Bin23988.jpg
# ./DataSet1/Bin3792.jpg
# ./DataSet1/Bin20958.jpg
# ./DataSet1/Bin2975.jpg
# ./DataSet1/Bin1225.jpg
# ./DataSet1/Bin19856.jpg
# ./DataSet1/Bin21190.jpg
# ./DataSet1/Bin25215.jpg
# ./DataSet1/Bin37696.jpg
# ./DataSet1/Bin43489.jpg
# ./DataSet1/Bin34512.jpg
# ./DataSet1/Bin2591.jpg
# ./DataSet1/Bin13259.jpg
# ./DataSet1/Bin1596.jpg
# ./DataSet1/Bin26158.jpg
# ./DataSet1/Bin37164.jpg
# ./DataSet1/Bin36697.jpg
# ./DataSet1/Bin43001.jpg
# ./DataSet1/Bin7065.jpg
# ./DataSet1/Bin22981.jpg
# ./DataSet1/Bin955.jpg
# ./DataSet1/Bin12192.jpg
# ./DataSet1/Bin11551.jpg
# ./DataSet1/Bin20979.jpg
# ./DataSet1/Bin40038.jpg
# ./DataSet1/Bin28968.jpg
# ./DataSet1/Bin21427.jpg
# ./DataSet1/Bin24134.jpg
# ./DataSet1/Bin30600.jpg
# ./DataSet1/Bin17060.jpg
# ./DataSet1/Bin18826.jpg
# ./DataSet1/Bin4051.jpg
# ./DataSet1/Bin11645.jpg
# ./DataSet1/Bin44631.jpg
# ./DataSet1/Bin40951.jpg
# ./DataSet1/Bin16213.jpg
# ./DataSet1/Bin9162.jpg
# ./DataSet1/Bin17093.jpg
# ./DataSet1/Bin40487.jpg
# ./DataSet1/Bin9026.jpg
# ./DataSet1/Bin44158.jpg
# ./DataSet1/Bin20923.jpg
# ./DataSet1/Bin44601.jpg
# ./DataSet1/Bin41069.jpg
# ./DataSet1/Bin7487.jpg
# ./DataSet1/Bin15692.jpg
# ./DataSet1/Bin11771.jpg
# ./DataSet1/Bin45809.jpg
# ./DataSet1/Bin16153.jpg
# ./DataSet1/Bin6812.jpg
# ./DataSet1/Bin14421.jpg
# ./DataSet1/Bin48229.jpg
# ./DataSet1/Bin10326.jpg
# ./DataSet1/Bin1447.jpg
# ./DataSet1/Bin11623.jpg
# ./DataSet1/Bin22095.jpg
# ./DataSet1/Bin42213.jpg
# ./DataSet1/Bin23153.jpg
# ./DataSet1/Bin23233.jpg
# ./DataSet1/Bin14554.jpg
# ./DataSet1/Bin13059.jpg
# ./DataSet1/Bin33257.jpg
# ./DataSet1/Bin9646.jpg
# ./DataSet1/Bin20624.jpg
# ./DataSet1/Bin29598.jpg
# ./DataSet1/Bin36450.jpg
# ./DataSet1/Bin37598.jpg
# ./DataSet1/Bin58.jpg
# ./DataSet1/Bin26069.jpg
# ./DataSet1/Bin16981.jpg
# ./DataSet1/Bin5621.jpg
# ./DataSet1/Bin16460.jpg
# ./DataSet1/Bin48382.jpg
# ./DataSet1/Bin24384.jpg
# ./DataSet1/Bin39409.jpg
# ./DataSet1/Bin15497.jpg
# ./DataSet1/Bin28233.jpg
# ./DataSet1/Bin16991.jpg
# ./DataSet1/Bin36699.jpg
# ./DataSet1/Bin22897.jpg
# ./DataSet1/Bin43037.jpg
# ./DataSet1/Bin30717.jpg
# ./DataSet1/Bin18826.jpg
# ./DataSet1/Bin21854.jpg
# ./DataSet1/Bin48160.jpg
# ./DataSet1/Bin24285.jpg
# ./DataSet1/Bin7675.jpg
# ./DataSet1/Bin13210.jpg
# ./DataSet1/Bin2441.jpg
# ./DataSet1/Bin33738.jpg
# ./DataSet1/Bin49863.jpg
# ./DataSet1/Bin30850.jpg
# ./DataSet1/Bin28412.jpg
# ./DataSet1/Bin45217.jpg
# ./DataSet1/Bin27600.jpg
# ./DataSet1/Bin38075.jpg
# ./DataSet1/Bin46380.jpg
# ./DataSet1/Bin7060.jpg
# ./DataSet1/Bin27255.jpg
# ./DataSet1/Bin14326.jpg
# ./DataSet1/Bin47092.jpg
# ./DataSet1/Bin25976.jpg
# ./DataSet1/Bin37307.jpg
# ./DataSet1/Bin6911.jpg
# ./DataSet1/Bin10620.jpg
# ./DataSet1/Bin18891.jpg
# ./DataSet1/Bin26048.jpg
# ./DataSet1/Bin165.jpg
# ./DataSet1/Bin45526.jpg
# ./DataSet1/Bin33221.jpg
# ./DataSet1/Bin35888.jpg
# ./DataSet1/Bin28393.jpg
# ./DataSet1/Bin44741.jpg
# ./DataSet1/Bin17302.jpg
# ./DataSet1/Bin46027.jpg
# ./DataSet1/Bin30340.jpg
# ./DataSet1/Bin49678.jpg
# ./DataSet1/Bin1874.jpg
# ./DataSet1/Bin18991.jpg
# ./DataSet1/Bin13519.jpg
# ./DataSet1/Bin43023.jpg
# ./DataSet1/Bin39725.jpg
# ./DataSet1/Bin32820.jpg
# ./DataSet1/Bin20227.jpg
# ./DataSet1/Bin17318.jpg
# ./DataSet1/Bin34275.jpg
# ./DataSet1/Bin1536.jpg
# ./DataSet1/Bin13504.jpg
# ./DataSet1/Bin12811.jpg
# ./DataSet1/Bin22903.jpg
# ./DataSet1/Bin45303.jpg
# ./DataSet1/Bin5782.jpg
# ./DataSet1/Bin2495.jpg
# ./DataSet1/Bin6566.jpg
# ./DataSet1/Bin33266.jpg
# ./DataSet1/Bin30130.jpg
# ./DataSet1/Bin38873.jpg
# ./DataSet1/Bin17811.jpg
# ./DataSet1/Bin19117.jpg
# ./DataSet1/Bin35467.jpg
# ./DataSet1/Bin25606.jpg
# ./DataSet1/Bin33569.jpg
# ./DataSet1/Bin20760.jpg
# ./DataSet1/Bin16722.jpg
# ./DataSet1/Bin25214.jpg
# ./DataSet1/Bin38148.jpg
# ./DataSet1/Bin42795.jpg
# ./DataSet1/Bin26421.jpg
# ./DataSet1/Bin19789.jpg
# ./DataSet1/Bin11459.jpg
# ./DataSet1/Bin41721.jpg
# ./DataSet1/Bin40162.jpg
# ./DataSet1/Bin43596.jpg
# ./DataSet1/Bin1754.jpg
# ./DataSet1/Bin39636.jpg
# ./DataSet1/Bin297.jpg
# ./DataSet1/Bin41627.jpg
# ./DataSet1/Bin5041.jpg
# ./DataSet1/Bin9309.jpg
# ./DataSet1/Bin45889.jpg
# ./DataSet1/Bin36958.jpg
# ./DataSet1/Bin5292.jpg
# ./DataSet1/Bin26634.jpg
# ./DataSet1/Bin11950.jpg
# ./DataSet1/Bin6544.jpg
# ./DataSet1/Bin24943.jpg
# ./DataSet1/Bin20775.jpg
# ./DataSet1/Bin21249.jpg
# ./DataSet1/Bin30211.jpg
# ./DataSet1/Bin19900.jpg
# ./DataSet1/Bin6139.jpg
# ./DataSet1/Bin24560.jpg
# ./DataSet1/Bin16755.jpg
# ./DataSet1/Bin49906.jpg
# ./DataSet1/Bin40047.jpg
# ./DataSet1/Bin36217.jpg
# ./DataSet1/Bin10924.jpg
# ./DataSet1/Bin30320.jpg
# ./DataSet1/Bin31123.jpg
# ./DataSet1/Bin37182.jpg
# ./DataSet1/Bin8632.jpg
# ./DataSet1/Bin9727.jpg
# ./DataSet1/Bin39810.jpg
# ./DataSet1/Bin35286.jpg
# ./DataSet1/Bin17758.jpg
# ./DataSet1/Bin28056.jpg
# ./DataSet1/Bin37342.jpg
# ./DataSet1/Bin9896.jpg
# ./DataSet1/Bin20342.jpg
# ./DataSet1/Bin24989.jpg
# ./DataSet1/Bin46765.jpg
# ./DataSet1/Bin42669.jpg
# ./DataSet1/Bin19868.jpg
# ./DataSet1/Bin39995.jpg
# ./DataSet1/Bin14081.jpg
# ./DataSet1/Bin29779.jpg
# ./DataSet1/Bin17358.jpg
# ./DataSet1/Bin32029.jpg
# ./DataSet1/Bin68.jpg
# ./DataSet1/Bin7797.jpg
# ./DataSet1/Bin32778.jpg
# ./DataSet1/Bin27378.jpg
# ./DataSet1/Bin19077.jpg
# ./DataSet1/Bin6206.jpg
# ./DataSet1/Bin16388.jpg
# ./DataSet1/Bin45085.jpg
# -1.0
# 0.9921875
# -1.0
# 0.9921875
# -1.0
# 0.9921875
# Dataset size: 50000

# %%
from keras import backend as K
from keras.engine import InputSpec, Layer
from keras import initializers, regularizers, constraints

# From a PR that is not pulled into Keras
# https://github.com/fchollet/keras/pull/3677
# I updated the code to work on Keras 2.x

class MinibatchDiscrimination(Layer):
    """Concatenates to each sample information about how different the input
    features for that sample are from features of other samples in the same
    minibatch, as described in Salimans et. al. (2016). Useful for preventing
    GANs from collapsing to a single output. When using this layer, generated
    samples and reference samples should be in separate batches.
    # Example
    ```python
        # apply a convolution 1d of length 3 to a sequence with 10 timesteps,
        # with 64 output filters
        model = Sequential()
        model.add(Convolution1D(64, 3, border_mode='same', input_shape=(10, 32)))
        # now model.output_shape == (None, 10, 64)
        # flatten the output so it can be fed into a minibatch discrimination layer
        model.add(Flatten())
        # now model.output_shape == (None, 640)
        # add the minibatch discrimination layer
        model.add(MinibatchDiscrimination(5, 3))
        # now model.output_shape = (None, 645)
    ```
    # Arguments
        nb_kernels: Number of discrimination kernels to use
            (dimensionality concatenated to output).
        kernel_dim: The dimensionality of the space where closeness of samples
            is calculated.
        init: name of initialization function for the weights of the layer
            (see [initializations](../initializations.md)),
            or alternatively, Theano function to use for weights initialization.
            This parameter is only relevant if you don't pass a `weights` argument.
        weights: list of numpy arrays to set as initial weights.
        W_regularizer: instance of [WeightRegularizer](../regularizers.md)
            (eg. L1 or L2 regularization), applied to the main weights matrix.
        activity_regularizer: instance of [ActivityRegularizer](../regularizers.md),
            applied to the network output.
        W_constraint: instance of the [constraints](../constraints.md) module
            (eg. maxnorm, nonneg), applied to the main weights matrix.
        input_dim: Number of channels/dimensions in the input.
            Either this argument or the keyword argument `input_shape`must be
            provided when using this layer as the first layer in a model.
    # Input shape
        2D tensor with shape: `(samples, input_dim)`.
    # Output shape
        2D tensor with shape: `(samples, input_dim + nb_kernels)`.
    # References
        - [Improved Techniques for Training GANs](https://arxiv.org/abs/1606.03498)
    """

    def __init__(self, nb_kernels, kernel_dim, init='glorot_uniform', weights=None,
                 W_regularizer=None, activity_regularizer=None,
                 W_constraint=None, input_dim=None, **kwargs):
        self.init = initializers.get(init)
        self.nb_kernels = nb_kernels
        self.kernel_dim = kernel_dim
        self.input_dim = input_dim

        self.W_regularizer = regularizers.get(W_regularizer)
        self.activity_regularizer = regularizers.get(activity_regularizer)

        self.W_constraint = constraints.get(W_constraint)

        self.initial_weights = weights
        self.input_spec = [InputSpec(ndim=2)]

        if self.input_dim:
            kwargs['input_shape'] = (self.input_dim,)
        super(MinibatchDiscrimination, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 2

        input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_dim))]

        self.W = self.add_weight(shape=(self.nb_kernels, input_dim, self.kernel_dim),
            initializer=self.init,
            name='kernel',
            regularizer=self.W_regularizer,
            trainable=True,
            constraint=self.W_constraint)

        # Set built to true.
        super(MinibatchDiscrimination, self).build(input_shape)

    def call(self, x, mask=None):
        activation = K.reshape(K.dot(x, self.W), (-1, self.nb_kernels, self.kernel_dim))
        diffs = K.expand_dims(activation, 3) - K.expand_dims(K.permute_dimensions(activation, [1, 2, 0]), 0)
        abs_diffs = K.sum(K.abs(diffs), axis=2)
        minibatch_features = K.sum(K.exp(-abs_diffs), axis=2)
        return K.concatenate([x, minibatch_features], 1)

    def compute_output_shape(self, input_shape):
        assert input_shape and len(input_shape) == 2
        return input_shape[0], input_shape[1]+self.nb_kernels

    def get_config(self):
        config = {'nb_kernels': self.nb_kernels,
                  'kernel_dim': self.kernel_dim,
                  'init': self.init.__name__,
                  'W_regularizer': self.W_regularizer.get_config() if self.W_regularizer else None,
                  'activity_regularizer': self.activity_regularizer.get_config() if self.activity_regularizer else None,
                  'W_constraint': self.W_constraint.get_config() if self.W_constraint else None,
                  'input_dim': self.input_dim}
        base_config = super(MinibatchDiscrimination, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
# Out:
# Using TensorFlow backend.

# %%
from keras.layers.convolutional import Conv2DTranspose
from keras.initializers import Constant
import numpy as np



def upsample_filt(size):
    factor = (size + 1) // 2
    if size % 2 == 1:
        center = factor - 1
    else:
        center = factor - 0.5
    og = np.ogrid[:size, :size]
    return (1 - abs(og[0] - center) / factor) * (1 - abs(og[1] - center) / factor)


def bilinear_upsample_weights(factor, number_of_classes):
    filter_size = factor*2 - factor%2
    weights = np.zeros((filter_size, filter_size, number_of_classes, number_of_classes),
                       dtype=np.float32)
    upsample_kernel = upsample_filt(filter_size)
    for i in range(number_of_classes):
        weights[:, :, i, i] = upsample_kernel
    return weights


def bilinear2x(x, nfilters):
	'''
    Ugh, I don't like making layers.
    My credit goes to: https://kivantium.net/keras-bilinear
    '''
	return Conv2DTranspose(nfilters, (4, 4),
        strides=(2, 2),
        padding='same',
		kernel_initializer=Constant(bilinear_upsample_weights(2, nfilters)))(x)

# %%
import os
import sys
import numpy as np
import random
from keras import models
from keras import optimizers
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, Conv2DTranspose, UpSampling2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.core import Dense, Activation, Flatten, Reshape, Dropout
from keras.layers import Input
from keras.optimizers import Adam, Adagrad, Adadelta, Adamax, SGD
from keras.callbacks import CSVLogger
# GAN doesn't like spare gradients (says ganhack). LeakyReLU better.
from keras.layers.advanced_activations import LeakyReLU
import scipy
import h5py


#import tensorflow as tf
#import keras
#keras.backend.get_session().run(tf.initialize_all_variables())



def build_enc( shape ) :
    return build_discriminator(shape, build_disc=False)



def build_discriminator( shape, build_disc=True ) :
    '''
    Build discriminator.
    Set build_disc=False to build an encoder network to test
    the encoding/discrimination capability with autoencoder...
    '''
    def conv2d( x, filters, shape=(4, 4), **kwargs ) :
        '''
        I don't want to write lengthy parameters so I made a short hand function.
        '''
        x = Conv2D( filters, shape, strides=(2, 2),
            padding='same',
            kernel_initializer=Args.kernel_initializer,
            **kwargs )( x )
        #x = MaxPooling2D()( x )
        x = BatchNormalization(momentum=Args.bn_momentum)( x )
        x = LeakyReLU(alpha=Args.alpha_D)( x )
        return x

    # https://github.com/tdrussell/IllustrationGAN
    # As proposed by them, unlike GAN hacks, MaxPooling works better for anime dataset it seems.
    # However, animeGAN doesn't use it so I'll keep it more similar to DCGAN.

    bin1 = Input( shape=shape )
    x = bin1

    # Warning: Don't batchnorm the first set of Conv2D.
    x = Conv2D( 64, (4, 4), strides=(2, 2),
        padding='same',
        kernel_initializer=Args.kernel_initializer )( x )
    x = LeakyReLU(alpha=Args.alpha_D)( x )
    # 32x32

    x = conv2d( x, 128 )
    # 16x16

    x = conv2d( x, 256 )
    # 8x8

    x = conv2d( x, 512 )
    # 4x4

    if build_disc:
        x = Flatten()(x)
        # add 16 features. Run 1D conv of size 3.
        #x = MinibatchDiscrimination(16, 3)( x )

        #x = Dense(1024, kernel_initializer=Args.kernel_initializer)( x )
        #x = LeakyReLU(alpha=Args.alpha_D)( x )

        # 1 when "real", 0 when "fake".
        x = Dense(1, activation='sigmoid',
            kernel_initializer=Args.kernel_initializer)( x )
        return models.Model( inputs=bin1, outputs=x )
    else:
        # build encoder.
        x = Conv2D(Args.noise_shape[2], (4, 4), activation='tanh')(x)
        return models.Model( inputs=bin1, outputs=x )



def build_gen( shape ) :
    def deconv2d( x, filters, shape=(4, 4) ) :
        '''
        Conv2DTransposed gives me checkerboard artifact...
        Select one of the 3.
        '''
        # Simpe Conv2DTranspose
        # Not good, compared to upsample + conv2d below.
        x= Conv2DTranspose( filters, shape, padding='same',
            strides=(2, 2), kernel_initializer=Args.kernel_initializer )(x)

        # simple and works
        #x = UpSampling2D( (2, 2) )( x )
        #x = Conv2D( filters, shape, padding='same' )( x )

        # Bilinear2x... Not sure if it is without bug, not tested yet.
        # Tend to make output blurry though
        #x = bilinear2x( x, filters )
        #x = Conv2D( filters, shape, padding='same' )( x )

        x = BatchNormalization(momentum=Args.bn_momentum)( x )
        x = LeakyReLU(alpha=Args.alpha_G)( x )
        return x

    # https://github.com/tdrussell/IllustrationGAN  z predictor...?
    # might help. Not sure.

    noise = Input( shape=Args.noise_shape )
    x = noise
    # 1x1x256
    # noise is not useful for generating images.

    x= Conv2DTranspose( 512, (4, 4),
        kernel_initializer=Args.kernel_initializer )(x)
    x = BatchNormalization(momentum=Args.bn_momentum)( x )
    x = LeakyReLU(alpha=Args.alpha_G)( x )
    # 4x4
    x = deconv2d( x, 256 )
    # 8x8
    x = deconv2d( x, 128 )
    # 16x16
    x = deconv2d( x, 64 )
    # 32x32

    # Extra layer
    x = Conv2D( 64, (3, 3), padding='same',
        kernel_initializer=Args.kernel_initializer )( x )
    x = BatchNormalization(momentum=Args.bn_momentum)( x )
    x = LeakyReLU(alpha=Args.alpha_G)( x )
    # 32x32

    x= Conv2DTranspose( 3, (4, 4), padding='same', activation='tanh',
        strides=(2, 2), kernel_initializer=Args.kernel_initializer )(x)
    # 64x64

    return models.Model( inputs=noise, outputs=x )

# %% [markdown]
# ###### import os
# import sys
# import numpy as np
# import random
# from keras import models
# from keras import optimizers
# from keras.layers import Input
# from keras.optimizers import Adam, Adagrad, Adadelta, Adamax, SGD
# from keras.callbacks import CSVLogger
# import scipy
# import h5py
#
# #import tensorflow as tf
# #import keras
# #keras.backend.get_session().run(tf.initialize_all_variables())
#
#
#
# def sample_bins( bins ):
#     reals = []
#     for i in range( Args.batch_sz ) :
#         j = random.randrange( len(bins) )
#         bin1 = bins[ j ]
#         reals.append( bin1 )
#     reals = np.array(reals)
#     return reals
#
#
#
# def binary_noise(cnt):
#     # Distribution of noise matters.
#     # If you use single ranf that spans [0, 1], training will not work.
#     # Well, for me at least.
#     # Either normal or ranf works for me but be sure to use them with randrange(2) or something.
#     #noise = np.random.normal( scale=Args.label_noise, size=((Args.batch_sz,) + Args.noise_shape) )
#
#     # Note about noise rangel.
#     # 0, 1 noise vs -1, 1 noise. -1, 1 seems to be better and stable.
#
#     noise = Args.label_noise * np.random.ranf((cnt,) + Args.noise_shape) # [0, 0.1]
#     noise -= 0.05 # [-0.05, 0.05]
#     noise += np.random.randint(0, 2, size=((cnt,) + Args.noise_shape))
#
#     noise -= 0.5
#     noise *= 2
#     return noise
#
#
#
# def sample_fake( gen ) :
#     noise = binary_noise(Args.batch_sz)
#     fakes = gen.predict(noise)
#     return fakes, noise
#
#
#
# def dump_batch(imgs, cnt, ofname):
#     '''
#     Merges cnt x cnt generated images into one big image.
#     Use the command
#     $ feh dump.png --reload 1
#     to refresh image peroidically during training!
#     '''
#     assert Args.batch_sz >= cnt * cnt
#
#     rows = []
#
#     for i in range( cnt ) :
#         cols = []
#         for j in range(cnt*i, cnt*i+cnt):
#             cols.append( imgs[j] )
#         rows.append( np.concatenate(cols, axis=1) )
#
#     alles = np.concatenate( rows, axis=0 )
#     alles = denormalize4gan( alles )
#     #alles = scipy.misc.imresize(alles, 200) # uncomment to scale
#     scipy.misc.imsave( ofname, alles )
#
#
#
# def build_networks():
#     shape = (Args.sz, Args.sz, 3)
#
#     # Learning rate is important.
#     # Optimizers are important too, try experimenting them yourself to fit your dataset.
#     # I recommend you read DCGAN paper.
#
#     # Unlike gan hacks, sgd doesn't seem to work well.
#     # DCGAN paper states that they used Adam for both G and D.
#     #opt  = optimizers.SGD(lr=0.0001, decay=0.0, momentum=0.9, nesterov=True)
#     #dopt = optimizers.SGD(lr=0.0001, decay=0.0, momentum=0.9, nesterov=True)
#
#     # lr=0.010. Looks good, statistically (low d loss, higher g loss)
#     # but too much for the G to create face.
#     # If you see only one color 'flood fill' during training for about 10 batches or so,
#     # training is failing. If you see only a few colors (instead of colorful noise)
#     # then lr is too high for the opt and G will not have chance to form face.
#     #dopt = Adam(lr=0.010, beta_1=0.5)
#     #opt  = Adam(lr=0.001, beta_1=0.5)
#
#     # vague faces @ 500
#     # Still can't get higher frequency component.
#     #dopt = Adam(lr=0.0010, beta_1=0.5)
#     #opt  = Adam(lr=0.0001, beta_1=0.5)
#
#     # better faces @ 500
#     # but mode collapse after that, probably due to learning rate being too high.
#     # opt.lr = dopt.lr / 10 works nicely. I found this with trial and error.
#     # now same lr, as we are using history to train D multiple times.
#     # I don't exactly understand how decay parameter in Adam works. Certainly not exponential.
#     # Actually faster than exponential, when I look at the code and plot it in Excel.
#     dopt = Adam(lr=0.0002, beta_1=Args.adam_beta)
#     opt  = Adam(lr=0.0001, beta_1=Args.adam_beta)
#
#     # too slow
#     # Another thing about LR.
#     # If you make it small, it will only optimize slowly.
#     # LR only has to be smaller than certain threshold that is data dependent.
#     # (related to the largest gradient that prevents optimization)
#     #dopt = Adam(lr=0.000010, beta_1=0.5)
#     #opt  = Adam(lr=0.000001, beta_1=0.5)
#
#     # generator part
#     gen = build_gen( shape )
#     # loss function doesn't seem to matter for this one, as it is not directly trained
#     gen.compile(optimizer=opt, loss='binary_crossentropy')
#     gen.summary()
#
#     # discriminator part
#     disc = build_discriminator( shape )
#     disc.compile(optimizer=dopt, loss='binary_crossentropy')
#     disc.summary()
#
#     # GAN stack
#     # https://ctmakro.github.io/site/on_learning/fast_gan_in_keras.html is the faster way.
#     # Here, for simplicity, I use slower way (slower due to duplicate computation).
#     noise = Input( shape=Args.noise_shape )
#     gened = gen( noise )
#     result = disc( gened )
#     gan = models.Model( inputs=noise, outputs=result )
#     gan.compile(optimizer=opt, loss='binary_crossentropy')
#     gan.summary()
#
#     return gen, disc, gan
#
#
#
# def train_autoenc( dataf ):
#     '''
#     Train an autoencoder first to see if your network is large enough.
#     '''
#     f = h5py.File( dataf, 'r' )
#     bins = f.get( 'bins' )
#
#     opt = Adam(lr=0.001)
#
#     shape = (Args.sz, Args.sz, 3)
#     enc = build_enc( shape )
#     enc.compile(optimizer=opt, loss='mse')
#     enc.summary()
#
#     # generator part
#     gen = build_gen( shape )
#     # generator is not directly trained. Optimizer and loss doesn't matter too much.
#     gen.compile(optimizer=opt, loss='mse')
#     gen.summary()
#
#     face = Input( shape=shape )
#     vector = enc(face)
#     recons = gen(vector)
#     autoenc = models.Model( inputs=face, outputs=recons )
#     autoenc.compile(optimizer=opt, loss='mse')
#
#     epoch = 0
#     while epoch < 200 :
#         for i in range(10) :
#             reals = sample_bins( bins  )
#             fakes, noises = sample_fake( gen )
#             loss = autoenc.train_on_batch( reals, reals )
#             epoch += 1
#             print(epoch, loss)
#         fakes = autoenc.predict(reals)
#         dump_batch(fakes, 4, "fakes.png")
#         dump_batch(reals, 4, "reals.png")
#     gen.save_weights(Args.genw)
#     enc.save_weights(Args.discw)
#     print("Saved", Args.genw, Args.discw)
#
#
#
# def load_weights(model, wf):
#     '''
#     I find error message in load_weights hard to understand sometimes.
#     '''
#     try:
#         model.load_weights(wf)
#     except:
#         print("failed to load weight, network changed or corrupt hdf5", wf, file=sys.stderr)
#         sys.exit(1)
#
#
#
# def train_gan( dataf ) :
#     gen, disc, gan = build_networks()
#
#     # Uncomment these, if you want to continue training from some snapshot.
#     # (or load pretrained generator weights)
#     #load_weights(gen, Args.genw)
#     #load_weights(disc, Args.discw)
#
#     logger = CSVLogger('loss.csv') # yeah, you can use callbacks independently
#     logger.on_train_begin() # initialize csv file
#     with h5py.File( dataf, 'r' ) as f :
#         bin1 = f.get( 'bins' )
#         run_batches(gen, disc, gan, bin1, logger, range(5000))
#     logger.on_train_end()
#
#
#
# def run_batches(gen, disc, gan, bins, logger, itr_generator):
#     history = [] # need this to prevent G from shifting from mode to mode to trick D.
#     train_disc = True
#     for batch in itr_generator:
#         # Using soft labels here.
#         lbl_fake = Args.label_noise * np.random.ranf(Args.batch_sz)
#         lbl_real = 1 - Args.label_noise * np.random.ranf(Args.batch_sz)
#
#         fakes, noises = sample_fake( gen )
#         reals = sample_bins( bins )
#         # Add noise...
#         # My dataset works without this.
#         #reals += 0.5 * np.exp(-batch/100) * np.random.normal( size=reals.shape )
#
#         if batch % 10 == 0 :
#             if len(history) > Args.history_sz:
#                 history.pop(0) # evict oldest
#             history.append( (reals, fakes) )
#
#         gen.trainable = False
#         #for reals, fakes in history:
#         d_loss1 = disc.train_on_batch( reals, lbl_real )
#         d_loss0 = disc.train_on_batch( fakes, lbl_fake )
#         gen.trainable = True
#
#         #if d_loss1 > 15.0 or d_loss0 > 15.0 :
#         # artificial training of one of G or D based on
#         # statistics is not good at all.
#
#         # pretrain train discriminator only
#         if batch < 20 :
#             print( batch, "d0:{} d1:{}".format( d_loss0, d_loss1 ) )
#             continue
#
#         disc.trainable = False
#         g_loss = gan.train_on_batch( noises, lbl_real ) # try to trick the classifier.
#         disc.trainable = True
#
#         # To escape this loop, both D and G should be trained so that
#         # D begins to mark everything that's wrong that G has done.
#         # Otherwise G will only change locally and fail to escape the minima.
#         #train_disc = True if g_loss < 15 else False
#
#         print( batch, "d0:{} d1:{}   g:{}".format( d_loss0, d_loss1, g_loss ) )
#
#         # save weights every 10 batches
#         if batch % 10 == 0 and batch != 0 :
#             end_of_batch_task(batch, gen, disc, reals, fakes)
#             row = {"d_loss0": d_loss0, "d_loss1": d_loss1, "g_loss": g_loss}
#             #logger.on_epoch_end(batch, row)
#
#
#
# _bits = binary_noise(Args.batch_sz)
# def end_of_batch_task(batch, gen, disc, reals, fakes):
#     try :
#         # Dump how the generator is doing.
#         # Animation dump
#         dump_batch(reals, 4, "reals.png")
#         dump_batch(fakes, 4, "fakes.png") # to check how noisy the image is
#         frame = gen.predict(_bits)
#         bin1 = os.path.join(Args.bin_dir, "frame_{:08d}.png".format(int(batch/10)))
#         dump_batch(frame, 4, bin1)
#         dump_batch(frame, 4, "frame.png")
#
#         serial = int(batch / 10) % 10
#         prefix = os.path.join(Args.snapshot_dir, str(serial) + ".")
#
#         print("Saving weights", serial)
#         gen.save_weights(prefix + Args.genw)
#         disc.save_weights(prefix + Args.discw)
#     except KeyboardInterrupt :
#         print("Saving, don't interrupt with Ctrl+C!", serial)
#         # recursion to surely save everything haha
#         end_of_batch_task(batch, gen, disc, reals, fakes)
#         raise
#
#
#
# def generate( genw, cnt ):
#     shape = (Args.sz, Args.sz, 3)
#     gen = build_gen( shape )
#     gen.compile(optimizer='sgd', loss='mse')
#     load_weights(gen, Args.genw)
#
#     generated = gen.predict(binary_noise(Args.batch_sz))
#     # Unoffset, in batch.
#     # Must convert back to unit8 to stop color distortion.
#     generated = denormalize4gan(generated)
#
#     for i in range(cnt):
#         ofname = "{:04d}.png".format(i)
#         scipy.misc.imsave( ofname, generated[i] )
#
#
#
# def main( argv ) :
#     if not os.path.exists(Args.snapshot_dir) :
#         os.mkdir(Args.snapshot_dir)
#     if not os.path.exists(Args.bin_dir) :
#         os.mkdir(Args.bin_dir)
#
#     # test the capability of generator network through autoencoder test.
#     # The argument is that if the generator network can memorize the inputs then
#     # it should be enough to GAN-generate stuff.
#     # Pretraining gen isn't that useful in gan training as
#     # the untrained discriminator will soon ruin everything.
#     #train_autoenc( "data.hdf5" )
#
#     # train GAN with inputs in data.hdf5
#     train_gan( "data.hdf5" )
#
#     # Lets generate stuff
#     #generate( "gen.hdf5", 256 )
# if __name__ == '__main__':
#     main(sys.argv)
